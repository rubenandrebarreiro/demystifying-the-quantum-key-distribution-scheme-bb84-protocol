# %% [markdown]
# ##### Demystifying <br> the Quantum Key Distribution Schemes
# ### BB84 Protocol
#
# ![Cover Banner Logo](imgs/bin/JPGs/others/cover-banner-logo.jpg)

# %% [markdown]
# #### Author
#
# * [**_Rúben André Letra Barreiro_**](https://rubenandrebarreiro.github.io/) <br> **_Student no. 42648_** <br> [**_r.barreiro@campus.fct.unl.pt_**](mailto:r.barreiro@campus.fct.unl.pt)

# %% [markdown]
# #### From
#
# * [**_Integrated Master (BSc. + MSc.) of_**](https://www.fct.unl.pt/en/education/course/integrated-master-computer-science) <br> [**_Computer Science and Engineering_**](https://www.fct.unl.pt/en/education/course/integrated-master-computer-science) <br> [**_Faculty of Sciences and Technology_**](https://www.fct.unl.pt/en) **_of_** [**_New University of Lisbon_**](https://www.unl.pt/en) <br> [**_(FCT NOVA | FCT/UNL)_**](https://www.fct.unl.pt/en), <br> **_Almada/Lisbon, Portugal_**

# %% [markdown]
# #### About Me
#
# ![My Protrait Photo (Rounded)](imgs/bin/PNGs/photos/protrait-photo-rounded.png)
#
# <br> <br>
# * I am a **_passionate_**, **_enthusiastic_**, **_dedicated_** and **_hard work student_**. <br> <br>
# * I am a student from [**_Faculty of Sciences and Technology_**](https://www.fct.unl.pt/en) of [**_New University of Lisbon_**](https://www.unl.pt/en) [**_(FCT NOVA | FCT/UNL)_**](https://www.fct.unl.pt/en), in **Portugal**. <br> <br>
# * I am currently in the 4th year of the [**_Integrated Master (BSc. + MSc) of Computer Science and Engineering_**](https://www.fct.unl.pt/en/education/course/integrated-master-computer-science).

# %% [markdown]
# #### _Definition of Quantum_
#
# * The **_Quantum_** it’s the **_smallest value_**, **_quantity_** *or* **_amount_**, which a ***Physics***’/***Mechanics***’ **_entity_**/**_property_** *can represent*. <br> <br>
# * This behaviours are represented in ***Physics***’/***Mechanics***’ *magnitudes*/*scales*, **_acting_** *and* **_operating_** *on the following* **_microscopic_** *levels*:<br> <br>
#
#     * **_Atomic_**:
#         * In the ***Physics***'/***Mechanics***' *magnitudes*/*scales* of the **_atoms_**;
#
#     * **_Subatomic_**:
#         * In the ***Physics***’/***Mechanics***’ *magnitudes*/*scales* where the *behaviours* of the **_particles_** occur (e.g., **_electrons_**, **_protons_** and **_protons_**) and the possible *connections* and *interactions* between **_atoms_** (e.g., **_atoms_** *bounded and grouped together*, *in blocks*, *forming* **_molecules_**);
#         <br> <br>
#
# * This notation *started to be commonly used* in ***Physics***’/***Mechanics***’, since 1990, when ***Max Planck*** *presented his research work* on **_Black-body Radiation_** (i.e., **_Thermal Radiation_**).<br> <br>
# * Thus, for that reason, the smallest known magnitude/scale is the **_Planck's Scale_** or **_Planck's Length_**, being *equal to the length of*: <br> <br>
#
#     * $ 1.616199 \times 10^{35} meters $

# %% [markdown]
# #### _What is the Quantum Physics/Mechanics?_
#
# * The **_Quantum Physics_**/**_Mechanics_** is a fundamental theory in **_physics_** and **_mechanics_**, *which describes the* **_nature_**, *at the previously shown and explained magnitudes/scales*. <br> <br>
# * Although, in the most of cases, the **_Quantum Physics/Mechanics_** are *relevant for describing* **_microscopic systems_**, but *their specific effects are not only noticeable on such a scale*. <br> <br>
# * The **_Quantum Physics/Mechanics_** *provides accurate descriptions for many previously unexplained phenomenons as* **_Black-body Radiation_** and **_Stable Electron's Orbits_**. <br> <br>
# * It's *considered by many experts and specialists*, the *best existing theory allowing the study of the* **_nature_** *itself and all its behaviours*.

# %% [markdown]
# #### _What is the Quantization?_
#
# * The **_Quantization_** is _the process of transition_ from a **_classical_** *understanding of physical phenomena*, to a *new understanding*, known as **_Quantum Physics/Mechanics_**. <br> <br>
# * This _new process_ was one of the _several processes and aspects_ responsible for the naming of **_Quantum Physics/Mechanics_**, *being one of its broadest foundations*. <br> <br>
# * In this context, something is said to be **_quantized_**, _if it only takes on_ **_definite values_**, *and no other value*, *between those definite values*. <br> <br>
# * **_Quantum Physics/Mechanics_** assume that **_the smallest value, quantity or amount of energy_**, in any **_Quantum System_** is **_quantized_** (i.e., *can only take on certain values*). <br> <br>
# * The fundamental notion of a ***Physics***’/***Mechanics***’ *entity/property* which can be **_quantized_**, it’s referred as the **_Hypothesis of Quantization_**. <br> <br>
# * This hypothesis means that, the _magnitude/scale_ of a **_Physics’/Mechanics’_** *entity/property can* **_only_** *assume* **_discrete values_**, which consist in _integer numbers multiples_ of a **_Quantum_**.

# %% [markdown]
# #### _What is an Atom?_
#
# * An **_Atom_** it’s the *smallest unit containing common matter*, which contains a *chemical element* and **_cannot be broken down_** *by any chemical mean*.<br> <br>
# * The **_Atom_** it’s composed by **_subatomic particles_** (as **_Protons_**, **_Electrons_** and **_Neutrons_**). <br> <br>
# * All the **_objects_** in the *solid*, *liquid*, *gaseous* and of *plasma* are composed of *neutral* or *ionized* **_Atoms_**. <br> <br>
# * The **_Atoms_** are *extremely small*, *having typical sizes in the range of* $ 100 $ $ picometers $ ($ 10^{-10} $ $ meters $, i.e., $ 10^{-7} $ $ millimeters $, or even, $ \frac{1}{254,000,000} $ $ inches $). <br> <br>
# * In fact, it’s for that reason, why it’s **_not possible_** to *predict precisely its behaviour*, using the **_Classical Physics/Mechanics_**. <br> <br>
# * This happen due to the **_Quantum Effects_**, making the current **_Atomic Models_** use **_Quantum Principles_** now, *to explain and predict better that behaviours*. <br> <br>
# * The _total number of_ **_Atoms_** *in the entire Universe it’s estimated in a range between* $ 4 \times 10^{78} $ and $ 6 \times 10^{79} $.

# %% [markdown]
# #### _Atoms vs. Particles vs. Molecules_
#
# * The **_Atoms_** are the **_smallest pieces of matter_**. <br> <br>
# * The **_Particles_** are the **_building blocks of matter_** (*and not matter itself*), *forming* an **_Atom_**. <br> <br>
# * The **_Molecules_** are sets of **_Atoms_** *grouped and bound together*, which are **_smallest pieces of Compounds_**. <br> <br> <br>
# * The **_Atoms_** *can be combined in several ways, in order to form new* **_Molecules_**, *which can be divided in two types*: <br> <br>
#
#   * **_Elements_**:
#     * **_Molecules_** *of only one type of* **_Atom_**;
#
#   * **_Compounds_**:
#     * **_Molecules_** *of two or more different types of* **_Atoms_**;

# %% [markdown]
# #### _Classical Physics/Mechanics vs. Quantum Physics/Mechanics_
#
# * So, basically, the main difference between the **_Classical Physics/Mechanics_** and the **_Quantum Physics/Mechanics_**, is precisely the *magnitudes/scales*, on each one of them operates. <br> <br>
#
# * Whereas **_Classical Physics/Mechanics_** operates at the **_macroscopic level_** of *magnitudes/scales*, the **_Quantum Physics/Mechanics_** operates at the **_microscopic level_** of *magnitudes/scales*. <br> <br>
#
# * The **_macroscopic level_** of *magnitudes/scales* it's referred to **_large-scale_** things. <br> <br>
#
# * The **_microscopic level_** of *magnitudes/scales* it's referred to **_small-scale_** things. <br> <br>
#
# * The **_Classical Physics/Mechanics_** studies and describes the motion of **_macroscopic objects_** such as *spacecrafts*, *planets*, *stars*, and *galaxies*. <br> <br>
#
# * It *provides extremely accurate results* as long as the domain of study is *restricted to large objects*, *and the speeds involved don't approach the* **_speed of light_**. <br> <br>
#
# * The **_Classical Physics/Mechanics_** are *simple*, but **_cannot_** *be applied to extremely small* **_particles_** *moving at very high speed, as the results may turn* **_inaccurate_**. <br> <br>
#
# * Think, in a **_macroscopic_** *level*, how **_hard_** it's to *determine the final states* in the following situations... Now, imagine if that happened in a **_microscopic_** *level*... <br> <br> <br>
#
# * > "*In the world of the very small, where particle and wave aspects of reality are equally significant, things do not behave in any way that we can understand from our experience of the everyday world*.
#   > *All pictures are false, and there is no physical analogy we can make to understand what goes on inside* ***Atoms***. ***Atoms*** *behave like* ***Atoms***, *nothing else*."
#   > - ***John Gribbin***

# %% [markdown]
# #### _From Classical Physics/Mechanics to. Quantum Physics/Mechanics_
#
# * Thus, most of **_Classical Physics'/Mechanics'_** theories *can be derived from* **_Quantum Physics/Mechanics_** as a *valid approximation at large* (or **_macroscopic_**) *scale*. <br> <br>
#
# * The **_Quantum Physics/Mechanics_** *differs from* **_Classical Physics/Mechanics_** in that, the *energy*, the *momentum*, the *angular momentum* and, the other *values*, *quantities or amounts*, of a *bound system are restricted to discrete values* (described by the *principle of* **_quantization_**, explained previously). <br> <br>
#
# * The **_objects_** have *characteristics* of **_particles_** and **_waves_** (**_Wave-Particle Duality_**), and *there are limits to the precision of which of these characteristics can be measured* (and, *this is known as the old and very famous* **_Principle of Uncertainty of Heisenberg_**. <br> <br>
#
# * So, the **_Quantum Physics/Mechanics_** *emerged gradually since the theories to explain observations which couldn't be explained and described by* **_Classical Physics/Mechanics_**.

# %% [markdown]
# #### _The Components of an Atom_
#
# * The _building blocks_ of **_Atoms_** _are positively charged_ **_Protons_** *(+)*, _neutral_ **_Neutrons_** *(N)* and _negatively charged_ **_Electrons_** *(-)*. <br> <br>
# * The **_Protons_** and **_Neutrons_** *are very similar in mass*, while **_Electrons_** *are much smaller and lighter*. <br> <br>
# * Many **_Atoms_** _consist of a positively charged_ **_Nucleus_** composed of **_Protons_** and **_Neutrons_**, _surrounded by a negatively charged "cloud" of_ **_Electrons_**. <br> <br>
# * At its most basic level, an **_Atom_** _is any_ **_Particle_** *of matter containing*, *at least*, _one_ **_Proton_** (which, it’s the case of the **_Hydrogen Atom_**). <br> <br>
# * Some **_Electrons_** and **_Neutrons_** may be present, but **_aren’t required_**!!! <br> <br>
# * The _calculation of the number of_ **_Atomic Particles_** *is used to indicate the number or amount of*:
#
#     * **_Protons_**, presented in the **_Nucleus_**;
#     * **_Electrons_**, presented in the **_Electrosphere_**;
#     * **_Neutrons_**, presented in the **_Nucleus_**; <br> <br>
# * The **_Electrons_**, _in the_ **_Electrosphere_** _are orbiting around the_ **_Protons_** and **_Electrons_**, in the **_Nucleus_** (_as demonstrated visually by the_ **_Bohr’s Model_**).

# %% [markdown]
# #### _Bit vs. Pbit vs. Qubit - Comparison Between Some Basic Units of Information_
#
# ![Bit (Classical Bit)](imgs/bin/PNGs/illustrations/bit-1.png)
#
# * **_Bit (Classical Bit)_** \[bit\]:
#
#    * *Basic Unit of* ***Clasical Information***; <br> <br>
#    * *Capable of existing in just one state* **only** (**0** or **1**), at a different time; <br> <br>
#     * **1D Point** *in* **only** *of the two state/points* (**0** *and* **1**); <br> <br>
#     * *Deterministic state*; <br> <br>
#     * ***n bits = n states/combinations***; <br> <br>
#     * ***Formula***:
#         * $ Bit = \{ 0 \lor 1 \} $ <br> <br>
#     * ***Other Properties***:
#         * $ Configurations = \{ \ 0 \ , \ 1 \ \} $
#         * $ Description =
#     \begin{bmatrix}
#     1 \\
#     0 \\
#     \end{bmatrix} $
#         * $ Observation = \{ \ 0 \ \} \ \ OR \ \ \{ \ 1 \ \} \ \ (Certainty) $
#         * $ Evolution = $
#     $ \begin{bmatrix}
#     0 & 1 \\
#     1 & 0 \\
#     \end{bmatrix} \ \ (Deterministic) $

# %% [markdown]
# #### _Bit vs. Pbit vs. Qubit - Comparison Between Some Basic Units of Information_
#
# ![Pbit (Probabilistic Bit)](imgs/bin/PNGs/illustrations/pbit-1.png)
#
# * **_Pbit (Probabilistic Bit)_** \[p'bit\]:
#     * *Uses the* **Bit** (*Basic Unit of* ***Clasical Information***), *as his basis*, *in a* ***random fashion***; <br> <br>
#     * *Capable of existing in just one state* **only** (**0** or **1**), at a different time; <br> <br>
#     * **2D Line** *between* **only** *one of the two state/points* (**0** *and* **1**); <br> <br>
#     * *Non-Deterministic/Probabilistic state*; <br> <br>
#     * ***n pbits = n states/combinations***; <br> <br>
#     * ***Formula***:
#         * $ Pbit = \{ \ 0 : p \ , 1 : ( 1 - p ) \ \} $ <br> <br>
#     * ***Other Properties***:
#         * $ Configurations = \{ \ 0 \ , 1 \ \} $
#         * $ Description = $
# $ \begin{bmatrix}
# p \\
# 1 - p \\
# \end{bmatrix} \ \ ( \ p \in \mathbb{R} \ ) $
#         * $ Observation = \{ \ 0 \ \} \ ( \ p \% \ ) \ \ OR \ \ \{ \ 1 \ \} \ ( \ [ 1 - p ] \% \ ) $
#         * $ Evolution = $
# $ \begin{bmatrix}
# 1 - q & r \\
# q & 1 - r \\
# \end{bmatrix} \ \ ( \ q \ , \ r \in \ \mathbb{R} \ ) \ \ (Stochastic) $

# %% [markdown]
# #### _Bit vs. Pbit vs. Qubit - Comparison Between Some Basic Units of Information_
#
# ![Qubit (Quantum Bit)](imgs/bin/PNGs/illustrations/qubit-1.png)
#
# * **_Qubit (Quantum Bit)_** \[kju.bit\] or \[k'bit\]:
#     * *Basic Unit of* ***Quantum Information***; <br> <br>
#     * *Capable of existing in just one state* **only** (**0** or **1**), at a differente time; <br> <br>
#     * **3D Sphere** (*usually represented by a* ***Bloch Sphere***) with ***0*** or ***1*** at the *poles* and an *infinite number of* ***superpositions*** *as* ***states/points*** *on the* ***Bloch Sphere***; <br> <br>
#     * *Non-Deterministic/Probabilistic state*; <br> <br>
#     * ***n qubits = 2<sup>n</sup> states/combinations***; <br> <br>
#     * ***Formula***:
#         * $ Qubit = \alpha \lvert 0 \rangle + \beta \lvert 1 \rangle $ <br> <br>
#     * ***Other Properties***:
#         * $ Configurations = \{ \ 0 \ , 1 \ \} $
#         * $ Description = $
# $ \begin{bmatrix}
# \alpha \\
# \beta \\
# \end{bmatrix} \ \ ( \ \alpha \ , \ \beta \in \ \mathbb{C} \ ) $
#         * $ Observation = \{ \ 0 \ \} \ ( \ | \ \alpha \ | ^{2}\% \ ) \ \ AND \ \ \{ \ 1 \ \} \ ( \ | \ \beta \ | ^{2}\% \ ) \ \ (Uncertainty) $
#         * $ Evolution = $
# $ \begin{bmatrix}
# u & v \\
# w & x \\
# \end{bmatrix} \ \ ( \ u \ , \ v \ , \ w \ , \ x \ \in \mathbb{R} \ ) \ \ (Unitary) $

# %% [markdown]
# #### _Bloch Sphere_
#
# * The **_Bloch Sphere_** is a *gemometrical representation* of the *pure state space* of a *two-level* ***Quantum Physical/Mechanical System (Qubit)***.<br> <br>
# * This *geometrical representation* was named after the *physicist* ***Felix Bloch*** (*23 October 1905 - 10 September 1983*).<br> <br>
# * The ***Bloch Sphere*** is an ***unit 2-sphere***, with ***antipodal points*** corresponding to a *pair of mutually* ***orthogonal state vectors***. <br> <br>
# * The *north* and *south poles* of the ***Bloch Sphere*** *are typically chosen to correspond to the* ***standard basis vectors*** $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $, respectively, *which in turn might correspond*, per example, *to the* ***spin-up*** ($ \uparrow $) and ***spin-down*** ($ \downarrow $) *states* of an ***Electron***, but *this choice can be arbitrary*. <br> <br>
# * The ***points*** *on the* ***surface*** *of the* ***Bloch Sphere*** *correspond to the* ***pure states*** *of the* ***Quantum Physics/Mechanics System***, *whereas the* ***interior points*** *correspond to the* ***mixed states***. <br> <br>
# * The ***Quantum Physics/Mechanics*** (including the ***Bloch Sphere***) is *mathematically formulated* in the ***Hilbert Space*** or ***Projective Hilbert Space***.

# %% [markdown]
# #### _Fundamentals of Quantum Computing_
#
# * Let's start with the following quote to reflect about the ***Fundamentals of Quantum Computing***:
#
#     * > "***Classical Computation*** *is like a* ***solo voice*** - *one line of pure tones succeeding each other*.
#       > ***Quantum Computation*** *is like a* ***symphony*** - *many lines of tones interfering with one another*."
#       > - ***Seth Lloyd***
#
# <br>
#
# * *The 14 most relevant principles and properties of* ***Quantum Physics/Mechanics*** *that are on the basis of* ***Quantum Computing***, *allowing its current development*, *are the following*: <br> <br>
#     1. ***Quantum Subsystems (Represented as Qubits or Quantum Registers)***; <br> <br>
#     2. ***Quantum Superposition of States***; <br> <br>
#     3. ***Quantum Entanglement of States***; <br> <br>
#     4. ***Quantum Teleportation***; <br> <br>
#     5. ***Initialisation of Quantum Subsystems***; <br> <br>
#     6. ***Reversibility of Quantum Subsystems***; <br> <br>
#     7. ***Quantum Operations (Quantum Logic Gates/Operators)***; <br> <br>
#     8. ***Quantum Systems (Represented as Quantum Circuits)***; <br> <br>
#     9. ***Uncertainty Principle (in Quantum States)***; <br> <br>
#     10. ***Rutherford's Scattering***; <br> <br>
#     11. ***Quantum Parallelism***; <br> <br>
#     12. ***Existence of Quantum Multiverse***;

# %% [markdown]
# #### _Quantum Subsystems (Represented as Qubits or Quantum Registers)_
#
# * In an ordinary ***Classical RAM*** *hardware module*, the common ***Quantum State*** *of several* ***Electrons*** *is interpreted as only one* ***Classical Bit***. <br> <br>
# * The ***logical state*** *is determined by the* ***expectation value*** *of its* ***register contents*** (i.e., ***tension*** *of a* ***capacitor***). <br> <br>
# * Due to *acting* and *performing operations* in ***atomic*** and ***subatomic levels***, as also, due to its *inherent random* and *uncertain behaviours*, it's a *little difficult to control and understand* the ***Quantum Computations***. <br> <br> <br>
# * For that reason, ***Quantum Computations*** have *higher probabilities of occurring erros* than in ***Classical Computations***, as presented following:
#     * $ P(Errors \ in \ Classical \ Computations) = 10^{-9}=0.00 \ 000 \ 000 \ 1 $, i.e., the *acceptable minimum values* for ***B.E.R.*** (***Bit Error Rate***); <br> <br>
#     * $ P(Errors \ in \ Quantum \ Computations)=10^{-3}=0.00 \ 1 $, i.e., the *acceptable minimum values* for ***Q.B.E.R.*** (***Quantum Bit Error Rate***); <br> <br> <br>
# * In a ***Quantum Computer***, the ***information*** *is represented directly as the common* ***Quantum State*** *of many* ***Quantum Subsystems*** (i.e., ***Qubits*** or ***Quantum Bits***). <br> <br>
# * Each ***Quantum Subsystem*** *is described by a combination of two* _**"pure" states**_ (i.e., _**"pure" basis**_ or ***basis states***) interpreted as $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $. <br> <br> <br>
# * This combinations can be made by many forms, like per example: <br> <br>
#     * ***Ground*** *and* ***Excited*** *States of an* ***Ion***; <br> <br>
#     * ***Spin*** *of a* ***Particle***; <br> <br>
#     * ***Polarisation*** *of a* ***Photon***; <br> <br> <br>
# * In ***Quantum Computing***, the ***Quantum Subsystems*** are represented by ***Qubits*** (***Quantum Bits***). <br> <br>
# * The ***Quantum Bits*** (***Qubits***) are represented, mainly, by:
#     * ***Physical Systems***;
#     * ***Control Devices***; <br> <br> <br>
# * The *most common types of* ***physical system*** which could potentially be used to *store a* ***Qubit*** (***Quantum Bit***) are:
#     * ***Atoms***;
#     * ***Ions***;
#     * ***Photons***;
#     * ***Electrons***; <br> <br> <br>
# * The respective *control devices* also used to represent ***Qubits*** (***Quantum Bits***), are basically, ***Quantum Operations (Quantum Logic Gates/Operators)***, that are *working together to act* as a **_Quantum Computer Memory_** and/or a **_Quantum Processor_**, i.e., ***Q.P.U.*** (***Quantum Processor Unit***). <br> <br> <br>
#
# * The *state space* of a ***Qubit*** (***Quantum Bit***) have ***2 dimensions***, represented by a ***2D Vector*** (***two-dimensional vector***): <br> <br>
#     * $ \lvert \Psi \rangle = \begin{bmatrix}
# \alpha \\
# \beta \\
# \end{bmatrix} \ \ ( \ \alpha \ , \ \beta \in \ \mathbb{C} \ ) $ <br> <br> <br>
#
# * The component $ \alpha $ it's the *fraction (i.e., probability) of occurring the* ***Quantum State 0*** (***Ground State***). <br> <br>
#
# * The component $ \beta $ it's the *fraction (i.e., probability) of occurring the* ***Quantum State 1*** (***Excited State***). <br> <br> <br>
#
# * Thus, the both ***Quantum State 0*** and ***Quantum State 1*** (i.e., ***Ground State*** and ***Excited State***), can be represented as: <br> <br>
#     * $ \lvert 0 \rangle = \begin{bmatrix}
# 1 \\
# 0 \\
# \end{bmatrix} $ <br> <br>
#     * $ \lvert 1 \rangle = \begin{bmatrix}
# 0 \\
# 1 \\
# \end{bmatrix} $

# %% [markdown]
# #### _Quantum Superposition of States_
#
# * The ***Quantum Superposition of States*** is *one of the most important fundamental principles of* ***Quantum Physics/Mechanics***. <br> <br>
# * In the ***Quantum World***, a *particle* would have a ***Quantum State***, which can be seen as being *composed by more than one other different and simultaneous* ***Quantum States*** also. <br> <br>
# * This principle states that, any two (or more) ***Quantum States*** *can be added together* (i.e., "*superposed*") and *the result will be another valid* ***Quantum State***, *represented by the sum of the values of the same two (or more)* ***Quantum States***. <br> <br>
# * These ***Quantum States***, when "*superposed*", *are both occurring at the same time*. <br> <br>
# * For example, in a ***Quantum Superposition of States*** *A* and *B*, it's *not occurring* the ***Quantum State*** *A* or the ***Quantum State*** *B*, but it's *occurring* the ***Quantum State*** *A* ***and*** the ***Quantum State*** *B*, *at the same exactly moment*!!! <br> <br>
# * This *defies the* ***Classical Interpretation of the World*** *we used to*, *where some object have* ***never two states at the same time***. <br> <br>
# * For example, a *lamp bulb never can be* ***turned on*** *and* ***turned off***, or, a *statement are never* ***true*** *and* ***false***, *at the same exactly time*. <br> <br>
# * This it's what's we commonly called, for so long, the ***Duality Principle***, and it's also, *one of the basis for the* ***data processing*** in the ***Classical Computing*** *paradigm*. <br> <br>
# * In mathematic terms, it refers to a property of solutions to the ***Schrödinger's Equation***, because since the ***Schrödinger's Equation*** is linear, *any linear combination of solutions will also be a solution*. <br> <br> <br>
# * A general and generic ***Quantum State*** it's represented as an equation of this kind: <br> <br>
#     * $ \lvert \Psi (t) \rangle = \sum_{n} C_{n}(t) \lvert \Phi_{n} \rangle $ <br> <br> <br>
# * One of the most common examples of this *fundamental principle* is the state of a ***Qubit (Quantum Bit)***, based in the previously mentioned ***Duality Principle***. <br> <br>
# * The ***Qubit*** ***(Quantum Bit)*** as used in ***Quantum Computing*** and ***Quantum Information Processing***, which is ***Quantum Superposition*** of the "*Basis States*" (i.e., $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $), where $ \alpha $ and $ \beta $ are *amplitutes of the probabilities of occurring* $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $, respectively: <br><br>
#     * $ \lvert qubit \rangle = \alpha \lvert 0 \rangle + \beta \lvert 1 \rangle $ <br> <br> <br>
#
# * Where, the **_Quantum State 0_** could be **_off_**, **_false_**, **_with no signal_**, **_not working_**, **_not finished_**, etc., in a **_negative fashion_**. <br> <br>
#
# * And, in *opposite direction*, the **_Quantum State 1_** could be **_on_**, **_true_**, **_with signal_**, **_working_**, **_finished_**, etc., in a **_positive fashion_**. <br> <br>
#
# * *Each one of the components* (i.e., *possibilities*) *associated to a* **_Quantum State_** *have a probability associated of happening in the* **_Classical World_**, because *we can only observe concrete, absolute and deterministic aspects* in the **_Classical World_**, as we know... <br> <br>
#
# * But in the **_Quantum World_**, *all this possibilities are always happening at the same time*, *with a such probability associated*, *in a* **_non-concrete_**, **_non-absolute_** *and* **_non-deterministic_** *fashion*!!! <br> <br>
#
# * Likely, in a **_Distribution of Probabilities_** with **_Discrete Values_**, the *sum of the values* of the **_Quantum States_** in a **_Quantum Superposition of States_** *must always be equal to 1.0 (100 %)*. <br> <br>
#
# * Thus, the *probabilities of occurring each state* in a **_Quantum Superposition of States_** are, in general, *neither 0.0 (0 %) nor 1.0 (100 %)*. <br> <br> <br>
#
# * The *sum of the probabilities of occurring* |0⟩ *and* |1⟩ in a **_Quantum Superposition of States_**, *can be calculated by the sum of its absoulte values* (i.e., *its modulo values*) *squared*, as the following presented:
#     * $ |\alpha|^{2} + |\beta|^{2} = 1 $, where $ \alpha, \beta \in [0,1] $ <br> <br> <br>
#
# * A *completely equilibrated* **_Quantum Superposition of States_** *with only two possible* **_Quantum States_** (i.e., with *50%/50% probability of occurring to both states*), *can have its probabilities calculated as the following*, with $ \alpha = \frac{1}{\sqrt{2}} $ and $ \beta = \frac{1}{\sqrt{2}} $:
#     * $ |\alpha|^2 + |\beta|^2 = 1 \Leftrightarrow |\frac{1}{\sqrt{2}}|^2 + |\frac{1}{\sqrt{2}}|^2 = 1 \Leftrightarrow (\frac{1}{\sqrt{2}})^2 + (\frac{1}{\sqrt{2}})^2 = 1 \Leftrightarrow $ <br> $ \Leftrightarrow \Bigl(\frac{1^2}{(\sqrt{2})^2}\Bigr) + \Bigl(\frac{1^2}{(\sqrt{2})^2}\Bigr) = 1 \Leftrightarrow \frac{1}{2} + \frac{1}{2} = 1 \Leftrightarrow 1 = 1 $ <br> <br> <br>
#
# * This is also possible to calculate, through a **_Equation System_** with *2 variables*:
#     * $ \begin{cases} \alpha = \frac{1}{\sqrt{2}} \\ \beta = \frac{1}{\sqrt{2}} \\ |\alpha|^2 + |\beta|^2 = 1 \Leftrightarrow |\frac{1}{\sqrt{2}}|^2 + |\frac{1}{\sqrt{2}}|^2 = 1 \Leftrightarrow (\frac{1}{\sqrt{2}})^2 + (\frac{1}{\sqrt{2}})^2 = 1 \Leftrightarrow \\ \Leftrightarrow \Bigl(\frac{1^2}{(\sqrt{2})^2}\Bigr) + \Bigl(\frac{1^2}{(\sqrt{2})^2}\Bigr) = 1 \Leftrightarrow \frac{1}{2} + \frac{1}{2} = 1 \Leftrightarrow 1 = 1 \end{cases} $ <br> <br> <br>
#
# * Therefore, it's obtained the following values for $ \alpha $ and $ \beta $:
#   * $ \therefore \alpha = \frac{1}{\sqrt{2}} \wedge \beta = \frac{1}{\sqrt{2}} $ <br> <br> <br>
#
# * It's due to this property that the **_Qubit (Quantum Bit)_** *can have two simultaneous states*. <br> <br> <br>
#
# * So, we have the following property for the **_Qubits (Quantum Bits)_**:
#   * $ 1 \ qubit = 2 \ processed \ states $; <br> <br> <br>
#
# * **_Notes_**:
#   * In **_Quantum Computing_** and **_Quantum Information Theory_**, a **_Quantum Superposition of States_** over a **_Qubit (Quantum Bit)_** are created using the **_Hadamard_** (**_H_**) **_Single Qubit Quantum Logic Gate/Operator_**;

# %% [markdown]
# #### _Quantum Entanglement of States_
#
# * Alongside the **_Quantum Superposition of States_** principle, this is one of the most *powerful* and *interesting* **_Fundamental Principle of Quantum Physics/Mechanics_**, with a *large usage* in **_Quantum Computing_**, most specificaly, in topics such as, **_Quantum Internet/Networks_**, **_Quantum Communication_** and **_Quantum Cryptography_**. <br> <br>
#
# * But, this **_Fundamental Principle of Quantum Physics/Mechanics_**, probably, it's also, the *weirdest* and *more difficult to understand*. <br> <br>
#
# * This **_Fundamental Principle of Quantum Physics/Mechanics_** is *the phenomenon occurring when two (or more)* **_atomic_** *or* **_subatomic particles_** *are* **_generated_**, **_interact_**, *or* **_share spatial proximity_**, *being* **_strongly connected_** *and* **_linked_** *to each other(s)*, *in a special way that*, *it's impossible to describe the* **_Quantum State_** *of one of them*, *without decribing also the other one(s)*, **_no matter how far apart they are_** *from each other(s)*!!! <br> <br>
#
# * The topic of **_Quantum Entanglement of States_** it's behind of the *huge disparity* and *difference* between the **_Classical Physics/Mechanics_** and the **_Quantum Physics/Mechanics_**. <br> <br>
#
# * In the 1930s, **_Albert Einstein_** was upset with **_Quantum Physics/Mechanics_** and *proposed a thought experiment where*, according to the theory, *an event at one point in the universe could affect another event arbitrarily far away*. <br> <br>
#
# * **_Albert Einstein_** called this experiment of, the "**_Spooky/Ghostly Action at a Distance_**" *because he thought it was absurd*!!! <br> <br>
#
# * It *seemed to imply communication faster than light*, something his "**_Theory of Relativity_**" completely *ruled out*... <br> <br>
#
# * *There is* **_no_** *equation for* **_Quantum Entanglement of States_**. <br> <br>
#
# * The **_Quantum Entanglement of States_** *it's only possible due to the principle of* **_Quantum Superposition of States_** *applied to* **_Multi-Particle Systems_** (or **_Multi-Qubit Systems_**). <br> <br> <br>
#
# * Consider *2 (two)* **_Particles_**, $ a $ and $ b $:
#   * The **_Quantum State_** for a *2 (two)* **_Particle System_** *is simply the tensor product of the 2 (two)* **_State Spaces_**; <br> <br>
#   * We can write the **_Quantum State_** of the *2 (two)* **_Particle System_** as:
#     * $ \lvert \Phi \rangle = \lvert a \rangle \otimes \lvert b \rangle \Leftrightarrow \lvert \Phi \rangle = \lvert ab \rangle $ <br> <br>
#   * This is just a compact notation that indicates that the left state corresponds to particle $ b $ and the right to particle $ b $. <br> <br>
#   * Now, *consider that each particle can be in* **_only one_** *of 2 (two) possible* **_Quantum States_**. <br> <br>
#   * For example, the **_Polarization State_** *of a* **_Photon_** *can be observed to be*, *in one of the following states*:
#     * **_Horizontal_** (**_Spin Left/Right_** - $ \leftrightarrow $);
#     * **_Vertical_** (**_Spin Up/Down_** - $ \updownarrow $); <br> <br>
#
#   * With the *2 (two)* **_Photons_**, *there are 4 (four) possible observed* **_Quantum States_**:
#     * $ \lvert \Phi \rangle = \lvert \leftrightarrow \leftrightarrow \rangle $
#     * $ \lvert \Phi \rangle = \lvert \leftrightarrow \updownarrow \rangle $
#     * $ \lvert \Phi \rangle = \lvert \updownarrow \leftrightarrow \rangle $
#     * $ \lvert \Phi \rangle = \lvert \updownarrow \updownarrow \rangle $ <br> <br>
#
#   * Now, let’s suppose that, *each of the 2 (two)* **_Photons_** *is in an equal* **_Quantum Superposition of States_** $ \leftrightarrow $ and $ \updownarrow $ **_Polarizations_**. <br> <br>
#
#   * Then, the **_Quantum State_** of the 2 (two) **_Photons' System_** is given by:
#     * $ \lvert \Phi \rangle = \frac{1}{2} \{ \ ( \ \lvert \leftrightarrow \rangle + \lvert \updownarrow \rangle \ ) \ \otimes \ ( \ \lvert \leftrightarrow \rangle + \lvert \updownarrow \rangle \ ) \ \} \Leftrightarrow $ <br> $ \Leftrightarrow \lvert \Phi \rangle = \frac{1}{2} \{ \ \lvert \leftrightarrow \leftrightarrow \rangle + \lvert \leftrightarrow \updownarrow \rangle + \lvert \updownarrow \leftrightarrow \rangle + \lvert \updownarrow \updownarrow \rangle \ \} $ <br> <br> <br>
#
#   * In the previous **_Quantum State_**, all the possible *outcomes* from the **_Quantum Measurements of States_** *are represented*. <br> <br>
#
#   * But now, consider the following Quantum State:
#     * $ \lvert \Phi \rangle = \frac{1}{\sqrt{2}} \{ \lvert \leftrightarrow \leftrightarrow \rangle + \lvert \updownarrow \updownarrow \rangle \} \Leftrightarrow \lvert \Phi \rangle = \frac{ \lvert \leftrightarrow \leftrightarrow \rangle + \lvert \updownarrow \updownarrow \rangle }{\sqrt{2}}  $ <br> <br> <br>
#
#   * *This is also an allowed* **_Quantum State_**!!! <br> <br>
#
#   * However, *2 (two) of the possible outcomes resulting from* **_Quantum Measurement of States_** *are missing*... <br> <br>
#
#   * But, this is a **_Quantum Entangled State_**!!! <br> <br>
#
#   * That means *the outcome resulted from the* **_Quantum Measurement of States_** *of 1 (one)* **_Particle_** *must be* **_correlated_** *with the outcome resulted from the* **_Quantum Measurement of States_** *of the other* **_Particle_**. <br> <br>
#
#   * Mathematically, the **_Quantum Entangled State_** *cannot be separated into the* **_tensor product_** *of 2 (two) individual* **_Particles_**, *which is how was started the treatment of the previous* **_Quantum System_** *of 2 (two)* **_Particles_**. <br> <br>
#
#   * The crucial difference between the **_Quantum Entangled State_** and the **_Non-Quantum Entangled State_** *is a reduced set of possible outcomes resulting from the* **_Quantum Measurement of States_**. <br> <br> <br>
#
#   * The same idea, can be applied to **_Qubits_** (**_Quantum Bits_**). <br> <br>
#
#   * With the *2 (two)* **_Qubits (Quantum Bits)_**, *there are 4 (four) possible observed* **_Quantum States_**:
#     * $ \lvert \Phi \rangle = \lvert 00 \rangle $
#     * $ \lvert \Phi \rangle = \lvert 01 \rangle $
#     * $ \lvert \Phi \rangle = \lvert 10 \rangle $
#     * $ \lvert \Phi \rangle = \lvert 11 \rangle $ <br> <br> <br>
#
#   * Suppose that each of the *2 (two)* **_Qubits (Quantum Bits)_** *is in an equal* **_Quantum Superposition of States_** *of* **_0_** *and* **_1_**. <br> <br>
#
#   * The **_Quantum State_** of the **_Quantum System_** of *2 (two)* **_Qubits (Quantum Bits)_** is given by:
#     * $ \lvert \Phi \rangle = \frac{1}{2} \{ \ ( \ \lvert 0 \rangle + \lvert 1 \rangle \ ) \ \otimes \ ( \ \lvert 0 \rangle + \lvert 1 \rangle \ ) \ \} \Leftrightarrow $ <br> $ \Leftrightarrow \lvert \Phi \rangle = \frac{1}{2} \{ \ \lvert 00 \rangle + \lvert 01 \rangle + \lvert 10 \rangle + \lvert 11 \rangle \ \} $ <br> <br> <br>
#
#   * Regarding the previous definition, the following **_Quantum State_** it's allowed: <br> <br>
#     * $ \lvert \Phi \rangle = \frac{1}{\sqrt{2}} \{ \lvert 00 \rangle + \lvert 11 \rangle \} \Leftrightarrow \lvert \Phi \rangle = \frac{ \lvert 00 \rangle + \lvert 11 \rangle }{\sqrt{2}}$ <br> <br> <br>
#
#   * And, *this previous* **_Quantum State_**, *it's also known as the* **_Bell State_**!!! <br> <br> <br>
#
#   * The **_Quantum Entanglement of States_** *with more than 2 (two)* **_Quantum Subsystems_**, *or* **_Qubits (Quantum Bits)_**, *are known as* **_GHZ States_**: <br> <br>
#     * $ \lvert \Phi \rangle = \frac{1}{\sqrt{2}} \{ \lvert 000 \rangle + \lvert 111 \rangle \} \Leftrightarrow \lvert \Phi \rangle = \frac{ \lvert 000 \rangle + \lvert 111 \rangle }{\sqrt{2}}$ <br> <br> <br>
#
# * ***Notes***:
#   * In **_Quantum Computing_** and **_Quantum Information Theory_**, a **_Quantum Entanglement of States_** *over 2 (two)*, *or more*, **_Qubits (Quantum Bits)_** *are created using the* **_Controlled-X (Controlled-NOT, CNOT, CX) Multi Qubit Quantum Logic Gate/Operator_**;

# %% [markdown]
# #### _Quantum Teleportation of States_
#
# * The **_Quantum Teleportation_** principle, uses the properties of **_Quantum Entanglement_** to send a **_Spin State_**, or a **_Qubit_** (**_Quantum Bit_**) *between the observers*, *without physically moving the involved particle*. <br> <br>
# * The **_Particles_** *themselves aren't really teleported*, *but the state of 1 (one) particle is* **_destroyed_** *on one side and* **_extracted_** *on the other side*, *so the information that the state* **_encodes_** *is* **_communicated_**. <br> <br>
# * The **_Quantum Teleportation_** *have the ability to send* **_Quantum Information_** *arbitrarily far distances without exposing* **_Quantum States_** to *thermal decoherence from the environment* or *other adverse effects*. <br> <br>
# * This principle allows to **_no particle be physically transported between locations_**, because **_the information it was already there_**!!! <br> <br>
# * Only *the information encoding the* **_Quantum State_** *is transferred*, *from a* **_Quantum State_** *in one location to another* **_Quantum State_** *elsewhere*, **_without replication_**. <br> <br>
# * The **_Quantum State_** *it's* **_never cloned_** *or* **_deleted_**, because *that would violate the* **_No-Cloning_** *and* **_No-Deletion_** *theorems of* **_Quantum Mechanics_**, thus, *the information is* **_always_** *preserved*!!!

# %% [markdown]
# #### _Quantum Operations (Quantum Logic Gates/Operators)_
#
# * The ***Quantum Operations*** (***Quantum Logic Gates/Operators***) can be distinguished, mainly, in two types:
#   * ***Single Qubit Quantum Logic Gates/Operators***;
#   * ***Multi Qubit Quantum Logic Gates/Operators***;

# %% [markdown]
# #### _Quantum Operations (Single Qubit Quantum Logic Gates/Operators)_
#
# * **_Pauli-I (I, Idle, Identity)_**:
#
#   * *Acts* on **only (one) single** ***Qubit*** (***Quantum Bit***); <br> <br>
#
#   * Is actually the absence (opaque) of a ***Quantum Logic Gate/Operator***; <br> <br>
#
#   * It ensures that nothing is applied to a ***Qubit*** (***Quantum Bit***) for one unit of ***Quantum Logic Gate/Operator*** time; <br> <br>
#
#   * Don't result at any changes to the ***Quantum Basis States*** $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $:
#     * $ \lvert 0 \rangle \rightarrow \lvert 0 \rangle $;
#     * $ \lvert 1 \rangle \rightarrow \lvert 1 \rangle $; <br> <br>
#
#   * Don't result at any changes to the ***Quantum Basis States*** $ \lvert + \rangle $ and $ \lvert - \rangle $:
#     * $ \lvert + \rangle \rightarrow \lvert + \rangle $;
#     * $ \lvert - \rangle \rightarrow \lvert - \rangle $; <br> <br>
#
#   * Don't result at any changes to the ***Quantum Basis States*** $ \lvert +i \rangle $ and $ \lvert -i \rangle $: <br>
#     * $ \lvert +i \rangle \rightarrow \lvert +i \rangle $;
#     * $ \lvert -i \rangle \rightarrow \lvert -i \rangle $; <br> <br>
#
#   * It's defined by the following ***Matrix Representation***:
#
#     * $ I = $
#     $ \begin{bmatrix}
# 1 & 0 \\
# 0 & 1 \\
# \end{bmatrix} \ \ (Pauli-I \ / \ Identity \ Matrix) $ <br> <br> <br>
#
#
# * **_Hadamard (H)_**:
#
#  * *Acts* on **only (one) single** ***Qubit*** (***Quantum Bit***); <br> <br>
#
#  * *Rotates* (or *flips*) the ***Qubit*** (***Quantum Bit***) 180° ($\pi$ radians) *C.C.W.* (*Counter Clockwise*) *around the* $ \frac{(\hat X + \hat Z)}{\sqrt{2}} $ *Axis* of the ***Bloch Sphere***; <br> <br>
#
#  * In other words, starts by *rotating* (or *flipping*) the ***Qubit*** (***Quantum Bit***) 180° ($ \pi $ radians) *around the Z-Axis* and then, *rotates* (or *flips*) the ***Qubit*** (***Quantum Bit***) again 90° ($ \frac{\pi}{2} $ radians) *C.C.W.* (*Counter Clockwise*), but now *around the Y-Axis*; <br> <br>
#
#  * Creates a ***Quantum Superposition of States***, when applied at the ***Quantum Basis States*** $ \lvert 0 \rangle $ or $ \lvert 1 \rangle $ of the Bloch Sphere; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $:
#    * $ \lvert 0 \rangle \rightarrow \lvert + \rangle $;
#    * $ \lvert 1 \rangle \rightarrow \lvert - \rangle $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert + \rangle $ and $ \lvert - \rangle $:
#    * $ \lvert + \rangle \rightarrow \lvert 0 \rangle $;
#    * $ \lvert - \rangle \rightarrow \lvert 1 \rangle $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert +i \rangle $ and $ \lvert -i \rangle $:
#    * $ \lvert +i \rangle \rightarrow \lvert -i \rangle $;
#    * $ \lvert -i \rangle \rightarrow \lvert +i \rangle $; <br> <br>
#
#  * It's defined by the following ***Matrix Representation***:
#    * $ H = \frac{1}{\sqrt{2}}$
#      $ \begin{bmatrix}
#  1 & 1 \\
#  1 & -1 \\
# \end{bmatrix} \ \ (Hadamard \ Matrix) $ <br> <br> <br>
#
# * **_Pauli-X (X, NOT, Bit Flip)_**:
#  * *Acts* on **only (one) single** ***Qubit*** (***Quantum Bit***); <br> <br>
#
#  * *Rotates* (or *flips*) the ***Qubit*** (***Quantum Bit***) 180° ($ \pi $ radians) *C.C.W. Counter Clockwise* *around the X-Axis* of the ***Bloch Sphere***; <br> <br>
#
#  * It's equivalent to the ***Classical NOT Gate***; <br> <br>
#
#  * It's also known as ***Bit Flip Gate*** or ***X Gate***; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $:
#    * $ \lvert 0 \rangle \rightarrow \lvert 1 \rangle $;
#    * $ \lvert 1 \rangle \rightarrow \lvert 0 \rangle $; <br> <br>
#
#  * Don't result at any changes to the ***Quantum Basis States*** $ \lvert + \rangle $ and $ \lvert - \rangle $:
#    * $ \lvert + \rangle \rightarrow \lvert + \rangle $;
#    * $ \lvert - \rangle \rightarrow \lvert - \rangle $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert +i \rangle $ and $ \lvert -i \rangle $:
#    * $ \lvert +i \rangle \rightarrow \lvert -i \rangle $;
#    * $ \lvert -i \rangle \rightarrow \lvert +i \rangle $; <br> <br>
#
#  * It's defined by the following ***Matrix Representation***:
#    * $ X = $
#     $ \begin{bmatrix}
# 0 & 1 \\
# 1 & 0 \\
# \end{bmatrix} \ \ (Pauli-X \ Matrix) $ <br> <br> <br>
#
# * **_Pauli-Y (Y)_**:
#  * *Acts* on **only (one) single** ***Qubit*** (***Quantum Bit***); <br> <br>
#
#  * *Rotates* (or *flips*) the ***Qubit*** (***Quantum Bit***) 180° ($ \pi $ radians) *C.C.W.* (*Counter Clockwise*) *around the Y-Axis* of the ***Bloch Sphere***; <br> <br>
#
#  * *Maps* $ \lvert 0 \rangle $ to $ i \lvert 1 \rangle $ and $ \lvert 1 \rangle $ to $ -i \lvert 0 \rangle $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $:
#    * $ \lvert 0 \rangle \rightarrow \lvert 1 \rangle $;
#    * $ \lvert 1 \rangle \rightarrow \lvert 0 \rangle $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert + \rangle $ and $ \lvert - \rangle $:
#    * $ \lvert + \rangle \rightarrow \lvert - \rangle $;
#    * $ \lvert - \rangle \rightarrow \lvert + \rangle $; <br> <br>
#
#  * Don't result at any changes to the ***Quantum Basis States*** $ \lvert +i \rangle $ and $ \lvert -i \rangle $:
#    * $ \lvert +i \rangle \rightarrow \lvert +i \rangle $;
#    * $ \lvert -i \rangle \rightarrow \lvert -i \rangle $; <br> <br>
#
#  * It's defined by the following ***Matrix Representation***:
#    * $ Y = $
#     $ \begin{bmatrix}
# 0 & -i \\
# i & 0 \\
# \end{bmatrix} \ \ (Pauli-Y \ Matrix) $ <br> <br> <br>
#
# * **_Pauli-Z (Z,_** $ R_{\pi} $ **_, Phase Flip)_**:
#  * *Acts* on **only (one) single** ***Qubit*** (***Quantum Bit***); <br> <br>
#
#  * *Rotates* (or *flips*) the ***Qubit*** (***Quantum Bit***) 180° ($ \pi $ radians) *C.C.W.* (*Counter Clockwise*) *around the Z-Axis* of the ***Bloch Sphere***; <br> <br>
#
#  * It's a special case of a ***Phase Shift*** ***Quantum Logic Gate/Operator*** with $ \phi = \pi $; <br> <br>
#
#  *  Don't result at any changes to the ***Quantum Basis States*** $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $:
#    * $ \lvert 0 \rangle \rightarrow \lvert 0 \rangle $;
#    * $ \lvert 1 \rangle \rightarrow \lvert 1 \rangle $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert + \rangle $ and $ \lvert - \rangle $:
#    * $ \lvert + \rangle \rightarrow \lvert - \rangle $;
#    * $ \lvert - \rangle \rightarrow \lvert + \rangle $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert +i \rangle $ and $ \lvert -i \rangle $:
#    * $ \lvert +i \rangle \rightarrow \lvert -i \rangle $;
#    * $ \lvert -i \rangle \rightarrow \lvert +i \rangle $; <br> <br>
#
#  * It's defined by the following ***Matrix Representation***:
#    * $ Z = $
#     $ \begin{bmatrix}
# 1 & 0 \\
# 0 & -1 \\
# \end{bmatrix} \ \ (Pauli-Z \ Matrix) $ <br> <br> <br>
#
# * **_Phase (_** $ R_{ \frac{\pi}{2} } $**_, S, P)_**:
#  * *Acts* on **only (one)** single ***Qubit*** (***Quantum Bit***); <br> <br>
#
#  * *Rotates* (or *flips*) the ***Qubit*** (***Quantum Bit***) 90° ($ \frac{\pi}{2} $ radians) *C.C.W.* (*Counter Clockwise*) *around the Z-Axis* of the ***Bloch Sphere***; <br> <br>
#
#  * It's a special case of a ***Phase Shift*** ***Quantum Logic Gate/Operator*** with $ \phi = \frac{\pi}{2} $; <br> <br>
#
#  *  Don't result at any changes to the ***Quantum Basis States*** $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $:
#    * $ \lvert 0 \rangle \rightarrow \lvert 0 \rangle $;
#    * $ \lvert 1 \rangle \rightarrow \lvert 1 \rangle $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert + \rangle $ and $ \lvert - \rangle $:
#    * $ \lvert + \rangle \rightarrow \lvert +i \rangle $;
#    * $ \lvert - \rangle \rightarrow \lvert -i \rangle $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert +i \rangle $ and $ \lvert -i \rangle $:
#    * $ \lvert +i \rangle \rightarrow \lvert - \rangle $;
#    * $ \lvert -i \rangle \rightarrow \lvert + \rangle $; <br> <br>
#
#  * It's defined by the following ***Matrix Representation***:
#    * $ R_{\frac{\pi}{2}} = $
#     $ \begin{bmatrix}
# 1 & 0 \\
# 0 & e^{i\frac{\pi}{2}} \\
# \end{bmatrix} \ \ (R_{\frac{\pi}{2}} \ Matrix) $ <br> <br> <br>
#
# * $ \frac{\pi}{8} $ **_(_** $ R_{\frac{\pi}{4}} $ **_, T)_**:
#  * *Acts* on **only (one) single** ***Qubit*** (***Quantum Bit***); <br> <br>
#
#  * *Rotates* (or *flips*) the ***Qubit*** (***Quantum Bit***) 45° ($ \frac{\pi}{4} $ radians) *C.C.W.* (*Counter Clockwise*) *around the Z-Axis* of the ***Bloch Sphere***; <br> <br>
#
#  * It's a special case of a ***Phase Shift Quantum Logic Gate/Operator*** with $ \phi = \frac{\pi}{4} $; <br> <br>
#
#  *  Don't result at any changes to the ***Quantum Basis States*** $ \lvert 0 \rangle $ and $ \lvert 1 \rangle $:
#    * $ \lvert 0 \rangle \rightarrow \lvert 0 \rangle $;
#    * $ \lvert 1 \rangle \rightarrow \lvert 1 \rangle $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert + \rangle $ and $ \lvert - \rangle $:
#    * $ \lvert + \rangle \rightarrow \frac{1}{\sqrt{2}} \times (\lvert + \rangle + \lvert +i \rangle) $;
#    * $ \lvert - \rangle \rightarrow \frac{1}{\sqrt{2}} \times (\lvert - \rangle + \lvert -i \rangle) $; <br> <br>
#
#  * Performs the following *Mappings* to the ***Quantum Basis States*** $ \lvert +i \rangle $ and $ \lvert -i \rangle $:
#    * $ \lvert +i \rangle \rightarrow \frac{1}{\sqrt{2}} \times (\lvert +i \rangle + \lvert - \rangle) $;
#    * $ \lvert -i \rangle \rightarrow \frac{1}{\sqrt{2}} \times (\lvert -i \rangle + \lvert + \rangle) $; <br> <br>
#
#  * It's defined by the following ***Matrix Representation***:
#    * $ R_{\frac{\pi}{4}} = $
#      $ \begin{bmatrix}
# 1 & 0 \\
# 0 & e^{i\frac{\pi}{4}} \\
# \end{bmatrix} \ \ (R_{\frac{\pi}{4}} \ Matrix) $

# %% [markdown]
# #### _Rutherford's Scattering_
#
# * This is probably the less *relevant* and *important principle of* ***Quantum Physics/Mechanics*** related to the ***Quantum Computing***... <br> <br>
#
# * The ***Rutherford's Scattering*** is the *elastic scattering of charged particles* by the ***Coulomb interaction***. <br> <br>
#
# * This *physical phenomenon* was *proposed* and *explained* by ***Ernest Rutherford***, *in 1911*. <br> <br>
#
# * This *experiment led to the development* of the ***Planetary Rutherford's Model of the Atom*** and eventually the ***Bohr's Model***, which later could be used to describe the ***Quantum System/State*** and the *probabilities of its possible states*... <br> <br>
#
# * The ***Rutherford's Scattering*** was first referred to as ***Coulomb's Scattering*** because it relies only upon the *static electric* (***Coulomb***) *potential* and *the minimum distance between particles is set entirely by this potential*. <br> <br>
#
# * The ***Classical Rutherford's Scattering Process*** of *alpha particles* against *gold nuclei* is an example of "***Elastic Scattering***" because *neither the alpha particles and not even the gold nuclei are internally excited*... <br> <br>
#
# * The ***Bohr's Model*** it's an improvement of the ***Rutherford's Model*** and is mostly a ***Quantum Physical*** interpretation of it. <br> <br>
#
# * It's a relatively primitive model of the ***Hydrogen Atom***, compared to the *valence shell atom*. <br> <br>
#
# * As a theory, it can be derived as a first-order approximation of the ***Hydrogen Atom*** using the *broader and much more accurate* ***Quantum Physics/Mechanics***, and thus, may be considered to be an *obsolete scientific theory*. <br> <br>
#
# * However, because of its *simplicity* and its *correct results for some selected systems*, the ***Bohr's Model*** is still very popular to introduce students to ***Quantum Physics/Mechanics*** or *diagrams of energy levels before moving on to the more accurate*, *but more complex*, *valence shell atom*...

# %% [markdown]
# #### _Quantum Parallelism_
#
# * The **_Quantum Parallelism_** arises from the ability of a **_Quantum Register_** in a **_Quantum Memory_** to exist in a **_Quantum Superposition of States_**. <br> <br>
#
# * The **_Quantum Parallelism_** is a *fundamental feature* of many **_Quantum Algorithms_**. <br> <br>
#
# * From this feature, it's possible for a **_Quantum Computer_** to *evaluate a function* $ f(x) $ *on many different values of* $ x $, **_simultaneosuly_**. <br> <br>
#
# * Thus, a **_Quantum Computer_** *can evaluate* $ f(x) $ *with the following argument assignments* ($ x=a \wedge x=b $), *at once*, **_in an only one single step_**!!! <br> <br>
#
# * In opposite fashion to the **_Classical Parallelism_**, where *multiple* **_Classical Circuits_**, *each built to* **_compute_** and **_evaluate_** the *function* $ f(x) $, are *executed* **_simultaneosuly_**, in the **_Quantum Parallelism_**, one single **_Quantum Circuit_** *is built to* **_compute_** and **_evaluate_** *function* $ f(x) $ with *multiple values of the argument* $ x $, **_simultaneously_**, *exploiting and taking advantage from the ability* of a **_Quantum Computer_** to be in a **_Quantum Superposition of States_**. <br> <br>

# %% [markdown]
# #### _Existence of Quantum Multiverse_
#
# * The ***Multiverse***, also known as a ***Maniverse***, ***Megaverse***, ***Metaverse***, ***Omniverse***, or ***Meta-Universe***, is a *hypothetical group of multiple universes*. <br> <br>
#
# * Together, *these universes comprise everything that exists*, i.e., *the entirety of space*, *time*, *matter*, *energy*, *and the physical laws and constants that describe them*. <br> <br>
#
# * *The different universes within the* ***Multiverse*** *are called* "***Parallel Universes***", "***Other Universes***", or "***Alternate Universes***". <br> <br>
#
# * *One interpretation for this existence of* ***Multiverse*** *it's the* ***Many-Worlds Interpretation***. <br> <br>
#
# * The ***Many-Worlds Interpretation*** implies that *there's a very large* (*maybe*, *infinite*) *number of universes*. <br> <br>
#
# * *It's one of many multiverse hypotheses in* ***Physics*** *and* ***Philosophy***. <br> <br>
#
# * The ***Many-Worlds Interpretation*** *views time as a many-branched tree*, *which in each branch of this tree*, *one of the every possible outcomes* from the ***Quantum System*** *is realized*. <br> <br>
#
# * *This is intended to resolve the correlation paradoxes of* ***Quantum Theory***, *such as the* ***E.P.R. Paradox*** (***Einstein-Podolsky-Rosen Paradox***) and the ***Schrödinger's Cat***, *since every possible outcome of a* ***Quantum Event*** *exists in its own universe*!!! <br> <br>
#
# * Since, *the experiment of the* ***Schrödinger's Cat*** *have two possible outcomes*, *each one of them it would exist in its own universe*...

# %% [markdown]
# #### _The BB84 Protocol - Introduction_
#
# * The **_BB84 Protocol_** is a **_Quantum Key Distribution Scheme_**, developed by **_Charles Bennett_** and **_Gilles Brassard_**, in **_1984_**. <br> <br>
# * *It is* **_one of the best known_** *(or maybe,* ***the best known***_)_ **_Quantum Key Distribution Scheme_** *and it is very used as an introduction for the* **_Quantum Cryptography_** *topic*. <br> <br>
# * The name of the **_BB84 Protocol_** is due to the _initials of its creators_ and the _year of its invention_ ( **_B_**_ennett_ , **_B_**_rassard_ , _19**84**_ ). <br> <br>
# * This protocol it was *designed* and *built*, *based on* (and *taking advantage of*) some of the *principles* and *properties* of **_Quantum Physics_** and **_Quantum Mechanics_**. <br> <br>
# * The protocol is **_safe provable_**, *until the current days*, due to the property which says that *any attempt* to **_gain information_** *and* **_have access to it_**, *can* **_only_** *be made by a* **_Quantum Measurement of States_**. <br> <br>
# * Any **_Quantum Measurement_** of a **_Quantum System_** *makes it* **_collapse_** *as a whole*, *resulting in a* **_deterministic_** *and* **_irreversible_** **_Classical State_**. <br> <br>
# * In other words, a **_Quantum Measurement of States_**, in this case, is **_only possible_** *at the expense of* **_disturbing the signal_**, *if the* **_two states_** *being attempted to distinguish* **_are not orthogonal (90º)_**, *during the* **_Secret Key transmission_**. <br> <br>
# * And, it is worthy to remember that *any attempt of do a completely* **_perfect copy_** *of some value of the* **_Secret Key_** *being transmitted it is also* **_not possible_**, *due to the* **_No Cloning Theorem_**, *which argues that an arbitrary* **_Quantum State_** *could not be copied faithfully*. <br> <br>
# * More precisely, the protocol can be seen as a **_"Half" or "Quasi" Quantum Key Distribution Scheme_** because it uses both, a **_Quantum Communication Channel_** and a **_Classical Communication Channel_**. <br> <br> <br>
# * The *brief complete procedure of this protocol* it is done, mainly, in **_two big steps_**: <br> <br>
#     1. **_Distribution/Transmission of a Secret Key, using a Quantum Communication Channel_**; <br> <br>
#     2. **_Exchange/Transmission of Private Messages, using a Classical Communication Channel and the Secret Key, previsouly distributed between the parties involved_**; <br> <br> <br>
# * This protocol it is explained as a *secure communication method*, *making usage of a* **_Secret Key_** *from a party (or **_client/user_**)* *to another party* *(or another **_client/user_**)* *for usage in an* **_OTP_** **_(One Time Pad) Encryption_**.

# %% [markdown]
# #### _The BB84 Protocol - A Quantum Key Distribution, during the COVID-19 quarantine/isolation_
#
# * In order to explain this **_Quantum Key Distribution Scheme_**, *I will tell a* **_very funny story_**!!! <br> <br> <br>
# * So, let's start by introducing the main actors/characters of the story... <br> <br> <br>
# ![Rúben Barreiro - Emoji](imgs/bitmojis-snapchat/PNGs/ruben-barreiro-emoji-1.png)
#
# * **_Rúben Barreiro_**: <br> <br>
#     * *A very ethusiastic* **_Student_** *from* **_FCT NOVA_**, **_Almada/Lisbon_**, **_Portugal_**; <br> <br>
#     * *Is currently in a **_Quantum Quest_** for success*; <br> <br>
#     * *Loves* **_Cryptography_**, **_Quantum Computing_** *and* **_Quantum Technologies_**; <br> <br>
#     * *Always dreamed about travel to* **_Paris_**, **_France_**; <br> <br> <br>
# ![Eleni Diamanti - Looking Right](imgs/bitmojis-snapchat/PNGs/eleni-diamanti-looking-right-1.png)
#
# * **_Eleni Diamanti_**: <br> <br>
#     * *A very kind* **_Professor_**, *teaching and lecturing at* **_Sorbonne Univerité_**, *in* **_Paris_**, **_France_**; <br> <br>
#     * *Works, as* **_Researcher_**, *at the* **_French National Centre for Scientific Research_**, *also in* **_Paris_**, **_France_**; <br> <br>
#     * *Met* **_Rúben_**, *in* **_Workshop of Quantum Computing_**, *at* **_Calouste Gulbenkian Foundation_**; <br> <br>
#     * *Also loves* **_Cryptography_**, **_Quantum Computing_** and **_Quantum Technologies_**; <br> <br> <br>
# ![Isabel Oitavém - Blink](imgs/bitmojis-snapchat/PNGs/isabel-oitavem-blink-1.png)
#
# * **_Isabel Oitavém_**: <br> <br>
#     * *A very nice* **_Professor_**, *teaching and lecturing at* **_FCT NOVA_**, *in* **_Almada/Lisbon_**, **_Portugal_**; <br> <br>
#     * *Works*, *as* **_Researcher_**, *at the* **_Centre for Mathematics and Applications_**, *also in* **_Almada/Lisbon_**, **_Portugal_**; <br> <br>
#     * *Helped* **_Rúben_**, *during his* **_Quantum Quest_** *for success*; <br> <br>
#     * *Loves* **_Cryptography_** *and*, *is very curious about* **_Quantum Computing_** *and* **_Quantum Technologies_**; <br> <br> <br>
# ![José Legatheaux - Bored](imgs/bitmojis-snapchat/PNGs/jose-legatheaux-bored-1.png)
#
# * **_José Legatheaux_**: <br> <br>
#     * *A very dummy* **_Professor_**, *teaching and lecturing at* **_FCT NOVA_**, *in* **_Almada/Lisbon_**, **_Portugal_**; <br> <br>
#     * *Works*, *as* **_Researcher_**, *at* **_NOVA-LINCS_**, *also in* **_Almada/Lisbon_**, **_Portugal_**; <br> <br>
#     * *Is a* **_very malicious agent_**, *who wants to harm* **_Rúben_**, *as much as possible*; <br> <br>
#     * *Is also known as the* **_"Father of Classical Internet"_**, *in* **_Portugal_** *and*, *he hates* **_Quantum Computing_**, **_Quantum Technologies_** *and*, *as obvious*... the **_Quantum Internet_**;

# %% [markdown]
# #### _The BB84 Protocol - A Quantum Key Distribution, during the COVID-19 quarantine/isolation_
#
# * *During the* **_quarantine/isolation_** *time*, *due to the* **_COVID-19 pandemic_**, *we were all obligated to* **_stay isolated_**, **_at home_** *and* **_away from our friends_**... <br> <br>
# * And, **_Eleni's birthday_** *was about to come and due to that* **_difficult times_**, *was* **_unable_** *to* **_organize her birthday party_**, *as usual*, *in other years*. <br> <br>
# * **_Eleni_** *started to be very* **_sad_** *and* **_depressed_**, *because she will* **_spend_** *her* **_birthday_** **_alone_**. <br> <br>
# * **_Rúben_** *was very* **_worried_** *about the* **_Eleni's state of spirit_** *and* **_wellfare_**... <br> <br>
# * *And because of that*, **_Rúben_** **_wanted a lot_** *to* **_put_** *a* **_smile_** *on* **_Eleni's face_**, *at least*, *for a while*. <br> <br>
# * **_Rúben_** *knew that* **_Eleni_** *started to* **_love_** *the* **_Portuguese customs_** *and* **_traditions_**, *during her* **_stay_**, *in* **_portuguese lands_**. <br> <br>
# * **_Rúben_** **_struggled a lot_** *to have some* **_brilliant idea_**, *in order to give a* **_special birthday's gift_** *to* **_Eleni_**, *some way*. <br> <br>
# * *Due to the* **_COVID-19 pandemic_**, **_Rúben_** *was also* **_unable_** *to* **_travel_** *to* **_Paris_**, *to met her*, *as expected*, *due to the lived moment*. <br> <br>
# * **_Rúben_** *remembered that* **_Eleni_** *always loved a* **_good bottle_** *of* **_red wine_**. <br> <br>
# * **_Rúben_** *thought in* **_offer_** *a* **_red wine bottle_** *to* **_Eleni_**!!! <br> <br>
# * *And*, *which* **_better wine_** *than the* **_Porto's Wine_**, *the* **_best wine_** *in* **_Portugal_** *and even in the* **_World_**?!! <br> <br>
# * *So*, **_Rúben_** **_decided_** *to* **_send to her_**, *a* **_Porto's Wine_** *bottle*, *by* **_mail_**. <br> <br>
# * *But a* **_sending mail_** *from* **_Portugal_** *to its destination*, *in* **_France_**, *it's still a* **_very turbulent shipping_** *and*, *even more*, *during a* **_COVID-19_** **_quarantine/isolation_**. <br> <br>
# * *Then*, *in order*, *to* **_protect_** *the* **_bottle_** *from it*, **_Rúben_** **_sent it_**, *inside a* **_safe_**. <br> <br>
# * *But*, *after* **_send it_**, **_Rúben_** *noticed he* **_forgot_** *about* **_send to her_**, *also*, *as an attachment*, *the* **_Secret Key_** *to* **_open it_**. <br> <br>
# * *Without the* **_Secret Key_**, **_Eleni_** *should* **_not_** *be able to* **_open_** *the* **_safe_**, *and get her so* **_desirable_** **_Porto's Wine_** *bottle*. <br> <br>
# * **_Rúben_**, **_mad with himself_**, *started to be* **_worried_** *and* **_stressed_** *about it*, *thinking on his huge* **_mistake_**. <br> <br>
# * *When* **_Eleni_** *received the* **_surprise gift_**, *inside the* **_safe_**, *noticed that it was missing the* **_Secret Key_** *to open it*... <br> <br>
# * **_Eleni_** *started to* **_cry_**, *desesperately*, *as the* **_World_** *it was* **_about to end_** *with* **_no idea_** *of what to do*... <br> <br>
# * *In order to* **_handle_** *with her* **_sadness_**, **_Eleni_** *started to* **_eat candies_** *and* **_watch TV Series_**, *as all* **_Women_** **_do_**, *when are* **_depressed_**. <br> <br>
# * *In that time*, **_Rúben_** *was having classes of his* **_Cryptography_** *course*, *with* **_Isabel_**. <br> <br>
# * **_Isabel_** *was a very* **_ethusiastic_** *about the* **_Cryptography_** *topic* *(such as* **_Rúben_** *was)*. <br> <br>
# * *As an expert in the topic*, **_Isabel_** *always* **_loved_** *to* **_teach_** *and* **_discuss_** *about* **_Secret Key Distribution_** *methods*. <br> <br>
# * **_Rúben_** *knew that*, *so decided to ask her for* **_help_**, *in order to* **_solve_** *his "little" problem*... <br> <br>
# * **_Isabel_**, *when she heard about all that* **_critical situation_**, **_decided_** *to* **_help_** *him*. <br> <br>
# * **_Rúben_** *told* **_Isabel_** *about a* **_Quantum Key Distribution Scheme_**, *called* **_BB84 Protocol_**, *which* **_Eleni_** **_teached_** *it to him*, *when they met*, *in* **_Lisbon_**. <br> <br>
# * *Thus*, *both* **_Rúben_** *and* **_Isabel_** *started to* **_discuss_** *and* **_plan_** *how to develop the* **_BB84 Protocol_**... <br> <br>
# * *They planned to use this* **_Quantum Key Distribution Scheme_**, *in order to* **_transmit_** *the* **_Secret Key_** *to* **_Eleni_**. <br> <br>
# * *At the end*, *they agreed that could be a very* **_hard_** *and* **_dangerous_** *proccess*, *which can result in a* **_great disaster_**, *but still* **_worth of trying_**... <br> <br>
# * **_Legatheaux_**, *that* **_little old "Niaiseux Arnaque Garçon Français"_**, *already suspected about all their* **_plans_**!!! <br> <br>
# * *He was a* **_very bad intentioned person_**, *who also lived in* **_France_** *for many years*. <br> <br>
# * *So*, *he*, *who was* **_hating_** *all that* **_French romantic sense_** *around the* **_Rúben's plans_**, *started to think about* **_sabotage_** *them*.

# %% [markdown]
# #### _The BB84 Protocol - Explanation_
#
# * Now, let me explain briefly the procedure of the **_Quantum Key Distribution_** behind of the **_BB84 Protocol_**... <br> <br>
# * In the **_BB84 Protocol_**, **_Rúben_** and **_Isabel_** want to send a **_Secret Key_** to **_Eleni_**. <br> <br>
# * Thus, both **_Rúben_** and **_Isabel_** *build two strings* (_"phrases"_ or *binary information sequence*), called $a$ and $b$, *each one of length* $n$. <br> <br>
# * Then, *they encode that* **_two strings of bits_** *as a* **_tensor product_** *of* $n$ **_qubits_**:
#     * $\lvert \Psi \rangle = \bigotimes_{i=1}^{n} \lvert \Psi_{a_{i}b_{i}} \rangle $, where $a_{i}$ and $b_{i}$ are the $i^{th}$ bits of $a$ and $b$, respectively; <br> <br> <br>
# * In order to *obtain a* **_tensor product_** *between* **_two vectorial spaces_**, in this case, we have:<br><br>
#    * $a^{\rightarrow} =
#  \begin{bmatrix}
#   a_{1} \\
#   a_{2} \\
#   ... \\
#   a_{n-1} \\
#   a_{n} \\
#   \end{bmatrix}
# $; <br> <br> <br>
# * In order to *obtain a* **_tensor product_** *between* **_two vectorial spaces_**, in this case, we have:<br><br>
#    * $b^{\rightarrow} =
#  \begin{bmatrix}
#   b_{1} \\
#   b_{2} \\
#   ... \\
#   b_{n-1} \\
#   b_{n} \\
#   \end{bmatrix}
# $; <br> <br> <br>
# * In order to *obtain a* **_tensor product_** *between* **_two vectorial spaces_**, in this case, we have:<br><br>
#    * $a^{\rightarrow}$ *is a* **_vectorial space_** *in* $\mathbb{R}^{n}$;
# <br> <br>
#    * $b^{\rightarrow}$ *is a* **_vectorial space_** *in* $\mathbb{R}^{n}$;
# <br> <br>
#    * $a^{\rightarrow} \bigotimes b^{\rightarrow} =
#  \begin{bmatrix}
#   a_{1} \times b_{1} \\
#   ... \\
#   a_{1} \times b_{n} \\
#   ... \\
#   a_{n-m} \times b_{n-m} \\
#   ... \\
#   a_{n} \times b_{1} \\
#   ... \\
#   a_{n} \times b_{n} \\
#   \end{bmatrix}$, *with* $m \in \mathbb{R}$ *and* $1 < m < n$; <br> <br>
#    * $dim(a^{\rightarrow} \bigotimes b^{\rightarrow}) = dim(a^{\rightarrow}) \times dim(b^{\rightarrow}) = n \times n$; <br> <br>
#    * *Where* $a^{\rightarrow} \bigotimes b^{\rightarrow}$ *is a* **_vectorial space_** *in* $\mathbb{R}^{n} \times \mathbb{R}^{n}$ *or*, *more precisely*, *in*  $(\mathbb{R}^{n})^{2}$; <br> <br> <br>
# * Together, $a_{i}$ *and* $b_{i}$, *provide us an* **_index_** *for the following* **four Quantum States** *of a* **_qubit_** (**_Quantum Bit_**):<br>
#    1. $\lvert \Psi_{00} \rangle = \lvert 0 \rangle$, *which is equivalent to the* **_Classical Bit Value of 0_** *(i.e.,* **_ground state_** *or* $\uparrow$*)*; <br> <br>
#    2. $\lvert \Psi_{10} \rangle = \lvert 1 \rangle$, *which is equivalent to the* **_Classical Bit Value of 1_** *(i.e.,* **_excited state_** *or* $\downarrow$*)*; <br> <br>
#    3. $\lvert \Psi_{01} \rangle = \lvert + \rangle = \frac{1}{\sqrt{2}} \lvert 0 \rangle + \frac{1}{\sqrt{2}} \lvert 1 \rangle$, *which is equivalente to a* **_Quantum Superposition of States_**, *based on the* **_positive X-axis_** *of the* **_Bloch Sphere_**; <br> <br>
#    4. $\lvert \Psi_{11} \rangle = \lvert - \rangle = \frac{1}{\sqrt{2}} \lvert 0 \rangle - \frac{1}{\sqrt{2}} \lvert 1 \rangle$, *which is equivalente to a* **_Quantum Superposition of States_**, *based on the* **_negative X-axis_** *of the* **_Bloch Sphere_**; <br> <br> <br>
# * Note that it is the **_bit_** $b_{i}$ *that decides in which* **_basis_**, *the* **_bit_** $a_{i}$ *is encoded* (*in a* **_Classical Computational Basis_** *or in a* **_Quantum Hadamard Basis_**, *i.e.*, *the basis of a* **_Quantum Superposition of States_**_)_. <br> <br>
# * So, the **_qubits_** (**_Quantum Bits_**) *are now in* **_Quantum States_** *which are* **_not mutually orthogonal_** and, *then*, *it is* **_impossible_** *to* **_distinguish all_** *of them with* **_certainty_** *without knowing* $b$. <br> <br>
# * Then, **_Rúben_** and **_Isabel_** send $\lvert \Psi \rangle$ to **_Eleni_** *through a* **_Public_** *and* **_Authenticated Communication Channel_**, *which we can call* $\varepsilon$, *per example*. <br> <br>
# * **_Eleni_** *receives a* **_Quantum State_** $\varepsilon(p) = \varepsilon(\lvert \Psi \rangle \langle \Psi \rvert)$, *where* $\varepsilon$ *represents both the* **_noise effects_** *in the* **_Quantum Communication Channel_** *and the* **_attempts_** *of* **_accessing_** *or* **_eavesdropping_** *to the same*, *made by a third party*, *who can be* **_Legatheaux_**, *in this example*. <br> <br>
# * After **_Eleni_** *receive the string of* **_qubits_** (**_Quantum Bits_**), *all the three parties involved*, *namely*, **_Rúben/Isabel_**, **_Eleni_** *and* **_Legatheaux_**, *have their own* **_Quantum States_**. <br> <br>
# * However, *as only* **_Rúben_**/**_Isabel_** *know the real content of the string* $b$, *it becames virtually* **_impossible_** *to both* **_Eleni_** *and* **_Legatheaux_** *be able to* **_distinguish_** *the* **_Quantum States_** *of the* **_qubits_** (**_Quantum States_**). <br> <br>
# * In the same way that, *after* **_Eleni_** *has received the* **_qubits_** (**_Quantum Bits_**), *it is known that* **_Legatheaux_** *could* **_not_** *have a copy of the* **_qubits_** (**_Quantum Bits_**) *sent*, *previously*, *through the* **_Quantum Communication Channel_**. <br> <br>
# * And this, *can be proved by the* **_No Cloning Theorem_** *which states*, *in this case*, *that* **_Legatheaux_** *could* **_only_** *have done it*, *if he had made* **_Quantum Measurements_** *on the* **_qubits_** (**_Quantum Bits_**). <br> <br>
# * This action would *collapse the* **_Quantum System_**, as a whole, and then, *it would be possible to detect his attempt of* **_eavesdropping_** *on the* **_Quantum Communication Channel_**, *during the* **_key transmission_**. <br> <br>
# * The **_Quantum Measurements of States_** possible performed by **_Legatheaux_**, however, *are at risk of disturbing a particular* **_qubit_** (**_Quantum Bit_**) *with the probability of* $\frac{1}{2}$ $(50\%)$, *if he "guess" the* **_wrong basis_**, *during a* **_Quantum Measurement of States_**. <br> <br>
# * **_Eleni_**, then, *generates a string of* **_random bits_** $b$' *with the* **_same length_** *of* $b$ and after do it, **_measures_** *the string of* **_qubits_** (**_Quantum Bits_**) *she received from* **_Rúben_**/**_Isabel_**.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import qiskit

# %%
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.12.0',
#  'qiskit-aer': '0.4.1',
#  'qiskit-ignis': '0.2.0',
#  'qiskit-ibmq-provider': '0.6.0',
#  'qiskit-aqua': '0.6.5',
#  'qiskit': '0.17.0'}

# %%
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, BasicAer, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *

# %%
# Import the IBM Q Experience
from qiskit import IBMQ

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# Importing the Matplotlib library
# %matplotlib inline

# %%
num_qubits = 15

# %%
ruben_and_isabel_quantum_register = QuantumRegister(num_qubits, name='ruben-isabel-qureg')
ruben_and_isabel_classical_register = ClassicalRegister(num_qubits, name='ruben-isabel-clreg')

# %%
ruben_and_isabel_quantum_circuit = QuantumCircuit(ruben_and_isabel_quantum_register, ruben_and_isabel_classical_register, name="Rúben's/Isabel's Quantum Circuit")

# %%
eleni_quantum_register = QuantumRegister(num_qubits, name='eleni-qureg')
eleni_classical_register = ClassicalRegister(num_qubits, name='eleni-clreg')

# %%
eleni_quantum_circuit = QuantumCircuit(eleni_quantum_register, eleni_classical_register, name="Eleni's Quantum Circuit")

# %%
legatheaux_quantum_register = QuantumRegister(num_qubits, name='legatheaux-qureg')
legatheaux_classical_register = ClassicalRegister(num_qubits, name='legatheaux-clreg')

# %%
legatheaux_quantum_circuit = QuantumCircuit(legatheaux_quantum_register, legatheaux_classical_register, name="Legatheaux's Quantum Circuit")

# %%
max_random_seed_ruben_and_isabel_secret_key = 2**num_qubits

# %%
print("The Maximum Random Seed of Rúben's/Isabel's Secret Key:")
max_random_seed_ruben_and_isabel_secret_key
# Out:
# The Maximum Random Seed of Rúben's/Isabel's Secret Key:
# 32768

# %%
ruben_and_isabel_secret_key = np.random.randint(0, high = max_random_seed_ruben_and_isabel_secret_key)

# %%
print("Rúben's/Isabel's Secret Key:")
ruben_and_isabel_secret_key
# Out:
# Rúben's/Isabel's Secret Key:
# 28715

# %%
ruben_and_isabel_secret_key_binary = np.binary_repr(ruben_and_isabel_secret_key, num_qubits)

# %%
print("Rúben's/Isabel's Secret Key, in binary format:")
ruben_and_isabel_secret_key_binary
# Out:
# Rúben's/Isabel's Secret Key, in binary format:
# '111000000101011'

# %%
# Encode the random Bits of the Rúben's/Isabel's Secret Key as Qubits
# By default, the Qubits of the IBM's Quantum Circuit are all set to |0>, initially
for ruben_and_isabel_secret_key_binary_index, ruben_and_isabel_secret_key_binary_value_digit in enumerate(ruben_and_isabel_secret_key_binary):
    # If the Secret Key has a '1', in the current index, change it |1>
    if ruben_and_isabel_secret_key_binary_value_digit == '1':
        ruben_and_isabel_quantum_circuit.x(ruben_and_isabel_quantum_register[ruben_and_isabel_secret_key_binary_index])

# %%
# The Rúben's/Isabel's Secret Key Polarisation Table
ruben_and_isabel_secret_key_polarisation_table = []

# %%
# Switch randomly about half qubits to diagonal basis
for ruben_and_isabel_secret_key_index in range(len(ruben_and_isabel_quantum_register)):
    
    ruben_and_isabel_polarisation_axis = np.random.random()
    
    # Rectilinear Up/Down (↕) Polarised Photon/Qubit
    if (ruben_and_isabel_polarisation_axis >= 0.0) and (ruben_and_isabel_polarisation_axis < 0.25):
    
        # Saves the Rectilinear Up/Down (↕) Polarised Photon/Qubit in
        # the Rúben's/Isabel's Secret Key Polarisation Table
        ruben_and_isabel_secret_key_polarisation_table.append("↕")
    
    # Diagonal North East/South West (⤢) Polarised Photon/Qubit
    elif (ruben_and_isabel_polarisation_axis >= 0.25) and (ruben_and_isabel_polarisation_axis < 0.5):   
        
        # Puts the current qubit in Quantum Superposition of States,
        # using a Hadamard Quantum Logic Gate
        ruben_and_isabel_quantum_circuit.h(ruben_and_isabel_quantum_register[ruben_and_isabel_secret_key_index])

        # Saves the Diagonal North East/South West (⤢) Polarised Photon/Qubit in
        # the Rúben's/Isabel's Secret Key Polarisation Table
        ruben_and_isabel_secret_key_polarisation_table.append("⤢")
   
    # Rectilinear Left/Right (↔) Polarised Photon/Qubit
    elif (ruben_and_isabel_polarisation_axis >= 0.5) and (ruben_and_isabel_polarisation_axis < 0.75):
    
        # Saves the Rectilinear Left/Right (↔) Polarised Photon/Qubit in
        # the Rúben's/Isabel's Secret Key Polarisation Table
        ruben_and_isabel_secret_key_polarisation_table.append("↔")
    
    # Rectilinear North West/South East (⤡) Polarised Photon/Qubit
    else:
        
        # Puts the current qubit in Quantum Superposition of States,
        # using a Hadamard Quantum Logic Gate
        ruben_and_isabel_quantum_circuit.h(ruben_and_isabel_quantum_register[ruben_and_isabel_secret_key_index])
        
        # Saves the Rectilinear North West/South East (⤡) Polarised Photon/Qubit in
        # the Rúben's/Isabel's Secret Key Polarisation Table
        ruben_and_isabel_secret_key_polarisation_table.append("⤡")

# %%
print("The Final Polarisation for Rúben's/Isabel's Secret Key is:")
ruben_and_isabel_secret_key_polarisation_table
# Out:
# The Final Polarisation for Rúben's/Isabel's Secret Key is:
# ['⤡', '↕', '↔', '↔', '⤢', '⤡', '↔', '↕', '↕', '⤡', '⤡', '⤡', '⤡', '⤡', '⤡']

# %%
def send_quantum_state(quantum_circuit_sender, quantum_circuit_receiver, quantum_register_receiver):
    
    quantum_state_to_send = quantum_circuit_sender.qasm().split(sep=';')[4:-1]
    
    quantum_register_literal_offset = (len(quantum_circuit_sender.qregs[0].name) + 3)
    
    for qubit_index, quantum_logic_gate_instruction in enumerate(quantum_state_to_send):
        
        
        quantum_state_to_send[qubit_index] = quantum_logic_gate_instruction.lstrip()
        
    for quantum_logic_gate_instruction in quantum_state_to_send:
        
        
        if (quantum_logic_gate_instruction[0] == 'x'):
            
            quantum_register_sender_index = int(quantum_logic_gate_instruction[quantum_register_literal_offset:-1])
            
            
            quantum_circuit_receiver.x(quantum_register_receiver[quantum_register_sender_index])
       
    
        elif (quantum_logic_gate_instruction[0] == 'h'):
            
            quantum_register_sender_index = int(quantum_logic_gate_instruction[quantum_register_literal_offset:-1])
            
            
            quantum_circuit_receiver.h(quantum_register_receiver[quantum_register_sender_index])
       
    
        elif (quantum_logic_gate_instruction[0] == 'm'):
            
            pass
      
    
        else:
            
            raise Exception('Unable to parse the Quantum Logic Gate Instruction...')

# %%
send_quantum_state(ruben_and_isabel_quantum_circuit, eleni_quantum_circuit, eleni_quantum_register)

# %%
ruben_and_isabel_quantum_circuit.draw(output = "mpl")

# %%
eleni_quantum_circuit.draw(output = "mpl")

# %%
# The Eleni's Secret Key Filtration for Measurement Table
eleni_secret_key_filtration_measurement_table = []

# %%
for eleni_secret_key_index in range(len(eleni_quantum_register)):
    
    eleni_filtration_measurement_axis = np.random.random()
    
    # Rectilinear Filter Up/Down/Left/Right (✛) for Measurement of a Polarised Photon/Qubit
    if ( (eleni_filtration_measurement_axis >= 0.0) and (eleni_filtration_measurement_axis < 0.25) ) or ( (eleni_filtration_measurement_axis >= 0.5) and (eleni_filtration_measurement_axis < 0.75) ):
    
        # Saves the Rectilinear Filter Up/Down/Left/Right (✛) for Measumerement of a Polarised Photon/Qubit in
        # the Eleni's Secret Key Filtration for Measurements Table
        eleni_secret_key_filtration_measurement_table.append("✛")
    
    # Diagonal North East/South West / North West/South East (✕) for Measurement of a Polarised Photon/Qubit
    elif ( (eleni_filtration_measurement_axis >= 0.25) and (eleni_filtration_measurement_axis < 0.5) ) or ( (eleni_filtration_measurement_axis >= 0.75) and (eleni_filtration_measurement_axis <= 1.0) ):   
        
        # Puts the current qubit in Quantum Superposition of States,
        # using a Hadamard Quantum Logic Gate
        eleni_quantum_circuit.h(eleni_quantum_register[eleni_secret_key_index])

        # Saves the Diagonal North East/South West / North West/South East (✕) for Measurement of a Polarised Photon/Qubit in
        # the Eleni's Secret Key Polarisation Table
        eleni_secret_key_filtration_measurement_table.append("✕")

# %%
print("The Final Filtration for Measurements for Eleni's Secret Key is:")
eleni_secret_key_filtration_measurement_table
# Out:
# The Final Filtration for Measurements for Eleni's Secret Key is:
# ['✛', '✛', '✛', '✛', '✛', '✕', '✛', '✕', '✕', '✕', '✕', '✛', '✛', '✕', '✛']

# %%
# Measure all Qubits of the Eleni's Quantum Circuit
for qubit_index in range(len(eleni_quantum_register)): 
    eleni_quantum_circuit.measure(eleni_quantum_register[qubit_index], eleni_classical_register[qubit_index])

# %%
eleni_quantum_circuit.draw(output = "mpl")

# %%
IBMQ.save_account('ea26fe9330806345fbd65092aaf40441d93ac9ad0fcb1fc299d02cc3dc1cc17c06480f83e99a7428e8ce46ad8b68ab45e645353f2bf6a4ead6bdf77431fe1589')
# Out:
# configrc.store_credentials:WARNING:2020-05-21 22:38:47,027: Credentials already present. Set overwrite=True to overwrite.

# %%
# Load the previously defined provider of Quantum Computers,
# to execute this program and simulation
my_provider = IBMQ.load_account()

# %%
# List the currently available Backends (i.e., the currently available Quantum Computers),
# to execute this program and simulation
my_provider.backends()
# Out:
# [<IBMQSimulator('ibmq_qasm_simulator') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmqx2') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_16_melbourne') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_vigo') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_ourense') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_london') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_burlington') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_essex') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_armonk') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibmq_rome') from IBMQ(hub='ibm-q', group='open', project='main')>]

# %%
# Execute the Eleni's Quantum Circuit 
quantum_machine_backend = BasicAer.get_backend('qasm_simulator')    
eleni_quantum_circuit_results = execute(eleni_quantum_circuit, backend = quantum_machine_backend, shots = 1).result()

# %%
# Execute the Eleni's Quantum Circuit 
#quantum_machine_backend = my_provider.get_backend('ibmq_16_melbourne')    
#eleni_quantum_circuit_results = execute(eleni_quantum_circuit, backend = quantum_machine_backend, shots = 1).result()

# %%
plot_histogram( eleni_quantum_circuit_results.get_counts( eleni_quantum_circuit ) )

# %%
# The results of the Quantum Measurement of States is Eleni's Secret Key Candidate
eleni_secret_key_binary_reversed = list(eleni_quantum_circuit_results.get_counts(eleni_quantum_circuit))[0]

# %%
# The Eleni's Secret Key is reversed so that
# first Qubit is the first element of the list
eleni_secret_key_binary = eleni_secret_key_binary_reversed[::-1]

# %%
eleni_secret_key = int(eleni_secret_key_binary, 2)

# %%
final_secret_key_qubits_to_keep = []
final_secret_key_qubits_to_discard = []

# %%
for final_secret_key_qubits_index, secret_key_quantum_state_basis in enumerate(zip(ruben_and_isabel_secret_key_polarisation_table, eleni_secret_key_filtration_measurement_table)):
    if ( ( secret_key_quantum_state_basis[0] == "↕" or secret_key_quantum_state_basis[0] == "↔" ) and secret_key_quantum_state_basis[1] == "✛"):
        print("Same basis choice for the qubit #{}: ".format(final_secret_key_qubits_index))
        final_secret_key_qubits_to_keep.append(final_secret_key_qubits_index)
    elif ( ( secret_key_quantum_state_basis[0] == "⤢" or secret_key_quantum_state_basis[0] == "⤡" ) and secret_key_quantum_state_basis[1] == "✕"):
        print("Same basis choice for the qubit #{}: ".format(final_secret_key_qubits_index))
        final_secret_key_qubits_to_keep.append(final_secret_key_qubits_index)
    else:
        print("Different basis choice for the qubit #{}: ".format(final_secret_key_qubits_index))
        final_secret_key_qubits_to_discard.append(final_secret_key_qubits_index)
        
    print(" - Basis chosen by Rúben/Isabel was: {}; ".format(secret_key_quantum_state_basis[0]))
    print(" - Basis chosen by Eleni was: {}; \n" .format(secret_key_quantum_state_basis[1]))
# Out:
# Different basis choice for the qubit #0:
#  - Basis chosen by Rúben/Isabel was: ⤡;
#  - Basis chosen by Eleni was: ✛;
#
# Same basis choice for the qubit #1:
#  - Basis chosen by Rúben/Isabel was: ↕;
#  - Basis chosen by Eleni was: ✛;
#
# Same basis choice for the qubit #2:
#  - Basis chosen by Rúben/Isabel was: ↔;
#  - Basis chosen by Eleni was: ✛;
#
# Same basis choice for the qubit #3:
#  - Basis chosen by Rúben/Isabel was: ↔;
#  - Basis chosen by Eleni was: ✛;
#
# Different basis choice for the qubit #4:
#  - Basis chosen by Rúben/Isabel was: ⤢;
#  - Basis chosen by Eleni was: ✛;
#
# Same basis choice for the qubit #5:
#  - Basis chosen by Rúben/Isabel was: ⤡;
#  - Basis chosen by Eleni was: ✕;
#
# Same basis choice for the qubit #6:
#  - Basis chosen by Rúben/Isabel was: ↔;
#  - Basis chosen by Eleni was: ✛;
#
# Different basis choice for the qubit #7:
#  - Basis chosen by Rúben/Isabel was: ↕;
#  - Basis chosen by Eleni was: ✕;
#
# Different basis choice for the qubit #8:
# ...

# %%
occasional_chance_accuracy = 0

# %%
for secret_key_qubit in zip(ruben_and_isabel_secret_key_binary, eleni_secret_key_binary):
    if ( secret_key_qubit[0] == secret_key_qubit[1] ):
        occasional_chance_accuracy += 1

# %%
percentage_qubits_to_keep = ( len( final_secret_key_qubits_to_keep ) / num_qubits )

# %%
measurement_convergence = ( occasional_chance_accuracy / num_qubits )

# %%
print("Percentage of Qubits (Quantum Bits) to be kept, according to Polarisation and Filtration for Measurements Tables comparison: \n - {} \n". format( percentage_qubits_to_keep ) )
print("Measurement convergence, i.e., the percentage of Qubits (Quantum Bits), occasionally, measured in the same basis), by additional occasional chance: \n - {}" .format( measurement_convergence ) )
# Out:
# Percentage of Qubits (Quantum Bits) to be kept, according to Polarisation and Filtration for Measurements Tables comparison:
#  - 0.5333333333333333
#
# Measurement convergence, i.e., the percentage of Qubits (Quantum Bits), occasionally, measured in the same basis), by additional occasional chance:
#  - 0.7333333333333333

# %%
ruben_and_isabel_final_secret_key_binary = [ruben_and_isabel_secret_key_binary[qubit_index] for qubit_index in final_secret_key_qubits_to_keep]
eleni_final_secret_key_binary = [eleni_secret_key_binary[qubit_index] for qubit_index in final_secret_key_qubits_to_keep]

# %%
final_accuracy_after_different_basis_discarded = 0

# %%
for final_secret_key_qubit in zip(ruben_and_isabel_final_secret_key_binary, eleni_final_secret_key_binary):
    if ( final_secret_key_qubit[0] == final_secret_key_qubit[1] ):
        final_accuracy_after_different_basis_discarded += 1

# %%
percentage_simlarity_final_secret_keys = final_accuracy_after_different_basis_discarded / len(ruben_and_isabel_final_secret_key_binary)

# %%
# NOTE: This should be always true, in a situation of no Eavesdropping and
#       after discarding the Qubits (Quantum Bits) measured in the different basis,
#       i.e., the Percentage of Similarity between the Rúben's/Isabel's and Eleni's Final Secret Key,
#       after the Qubits (Quantum Bits) measured in different basis, should be strictly equal to 1.0 (100%)
if (ruben_and_isabel_final_secret_key_binary == eleni_final_secret_key_binary) :
    print("The Secret Key exchange seems to worked fine and be completely secure!!!\n\n")
    
print("Percentage of Similarity between the Rúben's/Isabel's and Eleni's Final Secret Key, after the Qubits (Quantum Bits) measured in different basis: \n - {}" .format( percentage_simlarity_final_secret_keys ) )
# Out:
# The Secret Key exchange seems to worked fine and be completely secure!!!
#
#
# Percentage of Similarity between the Rúben's/Isabel's and Eleni's Final Secret Key, after the Qubits (Quantum Bits) measured in different basis:
#  - 1.0

# %%
ruben_and_isabel_final_secret_key = int("".join(str(binary_digit) for binary_digit in ruben_and_isabel_final_secret_key_binary), 2) 
eleni_final_secret_key = int("".join(str(binary_digit) for binary_digit in eleni_final_secret_key_binary), 2)

# %%
# The Secret Key wan't tampered and it's the same for both parties
if (percentage_simlarity_final_secret_keys == 1):
    print("The Secret Key exchange has been successful!!! \n")
    print(" - Rúben's/Isabel's Final Secret Key, in binary: \n  - ", ruben_and_isabel_final_secret_key_binary)
    print(" - Eleni's Final Secret Key, in binary: \n  - ", eleni_final_secret_key_binary)
    print("\n")
    print(" - Rúben's/Isabel's Final Secret Key: \n  - ", ruben_and_isabel_final_secret_key)
    print(" - Eleni's Final Secret Key: \n  - ", eleni_final_secret_key)
else:
    print("The Secret Key exchange has been tampered!!!\n\n")
    print("It's necessary to check for the existence of some Eavesdropper or try a new Secret Key exchange again...\n\n")
    print(" - Rúben's/Isabel's Final Secret Key, in binary: \n  - ", ruben_and_isabel_final_secret_key_binary)
    print(" - Eleni's Final Secret Key, in binary: \n  - ", eleni_final_secret_key_binary)
    print("\n")
    print(" - Rúben's/Isabel's Final Secret Key: \n  - ", ruben_and_isabel_final_secret_key)
    print(" - Eleni's Final Secret Key: \n  - ", eleni_final_secret_key)
# Out:
# The Secret Key exchange has been successful!!!
#
#  - Rúben's/Isabel's Final Secret Key, in binary:
#   -  ['1', '1', '0', '0', '0', '1', '0', '1']
#  - Eleni's Final Secret Key, in binary:
#   -  ['1', '1', '0', '0', '0', '1', '0', '1']
#
#
#  - Rúben's/Isabel's Final Secret Key:
#   -  197
#  - Eleni's Final Secret Key:
#   -  197

# %%
ruben_and_isabel_final_secret_key_binary_code = "".join(ruben_and_isabel_final_secret_key_binary)

# %%
eleni_final_secret_key_binary_code = "".join(eleni_final_secret_key_binary)

# %%
secret_message_from_ruben_and_isabel_to_eleni = "Bonjour!"

# %%
print('The secret message from Rúben/Isabel to Eleni: \n- ', secret_message_from_ruben_and_isabel_to_eleni)
# Out:
# The secret message from Rúben/Isabel to Eleni:
# -  Bonjour!

# %%
secret_message_from_ruben_and_isabel_to_eleni_ciphered = ''

# %%
for char_index, key_index in zip(secret_message_from_ruben_and_isabel_to_eleni, ruben_and_isabel_final_secret_key_binary_code):
    ciphered_char = chr(ord(char_index) + 2*ord(key_index) % 256)
    secret_message_from_ruben_and_isabel_to_eleni_ciphered += ciphered_char

# %%
print('Ciphered Message sent from Rúben/Isabel to Eleni:\n - ', secret_message_from_ruben_and_isabel_to_eleni_ciphered)
# Out:
# Ciphered Message sent from Rúben/Isabel to Eleni:
#  -  ¤ÑÎÊÏ×Ò

# %%
secret_message_from_ruben_and_isabel_to_eleni_plaintext = ''

# %%
for char_index, key_index in zip(secret_message_from_ruben_and_isabel_to_eleni_ciphered, eleni_final_secret_key_binary_code):
    deciphered_char = chr(ord(char_index) - 2*ord(key_index) % 256)
    secret_message_from_ruben_and_isabel_to_eleni_plaintext += deciphered_char

# %%
print('Plaintext Message received by Eleni from Rúben/Isabel:\n - ', secret_message_from_ruben_and_isabel_to_eleni_plaintext)
# Out:
# Plaintext Message received by Eleni from Rúben/Isabel:
#  -  Bonjour!

# %%
eleni_quantum_circuit = QuantumCircuit(eleni_quantum_register, eleni_classical_register, name="Eleni's Quantum Circuit")

# %%
send_quantum_state(ruben_and_isabel_quantum_circuit, legatheaux_quantum_circuit, legatheaux_quantum_register)

# %%
legatheaux_quantum_circuit.draw(output = "mpl")

# %%
legatheaux_secret_key_filtration_measurement_table = []

# %%
for legatheaux_secret_key_index in range(len(legatheaux_quantum_register)):
    
    legatheaux_filtration_measurement_axis = np.random.random()
    
    # Rectilinear Filter Up/Down/Left/Right (✛) for Measurement of a Polarised Photon/Qubit
    if ( (legatheaux_filtration_measurement_axis >= 0.0) and (legatheaux_filtration_measurement_axis < 0.25) ) or ( (legatheaux_filtration_measurement_axis >= 0.5) and (legatheaux_filtration_measurement_axis < 0.75) ):
    
        # Saves the Rectilinear Filter Up/Down/Left/Right (✛) for Measumerement of a Polarised Photon/Qubit in
        # the Legatheaux's Secret Key Filtration for Measurements Table
        legatheaux_secret_key_filtration_measurement_table.append("✛")
    
    # Diagonal North East/South West / North West/South East (✕) for Measurement of a Polarised Photon/Qubit
    elif ( (legatheaux_filtration_measurement_axis >= 0.25) and (legatheaux_filtration_measurement_axis < 0.5) ) or ( (legatheaux_filtration_measurement_axis >= 0.75) and (legatheaux_filtration_measurement_axis <= 1.0) ):   
        
        # Puts the current qubit in Quantum Superposition of States,
        # using a Hadamard Quantum Logic Gate
        legatheaux_quantum_circuit.h(legatheaux_quantum_register[legatheaux_secret_key_index])

        # Saves the Diagonal North East/South West / North West/South East (✕) for Measurement of a Polarised Photon/Qubit in
        # the Eleni's Secret Key Polarisation Table
        legatheaux_secret_key_filtration_measurement_table.append("✕")

# %%
print("The Final Filtration for Measurements for Legatheaux's Secret Key is:")
legatheaux_secret_key_filtration_measurement_table
# Out:
# The Final Filtration for Measurements for Legatheaux's Secret Key is:
# ['✕', '✕', '✕', '✕', '✕', '✕', '✛', '✛', '✕', '✛', '✛', '✛', '✕', '✕', '✕']

# %%
# Measure all Qubits of the Legatheaux's Quantum Circuit
for qubit_index in range(len(legatheaux_quantum_register)): 
    legatheaux_quantum_circuit.measure(legatheaux_quantum_register[qubit_index], legatheaux_classical_register[qubit_index])

# %%
legatheaux_quantum_circuit.draw(output = "mpl")

# %%
# Execute the Legatheaux's Quantum Circuit 
quantum_machine_backend = BasicAer.get_backend('qasm_simulator')    
legatheaux_quantum_circuit_results = execute(legatheaux_quantum_circuit, backend = quantum_machine_backend, shots = 1).result()

# %%
# Execute the Legatheaux's Quantum Circuit 
#quantum_machine_backend = my_provider.get_backend('ibmq_16_melbourne')    
#legatheaux_quantum_circuit_results = execute(legatheaux_quantum_circuit, backend = quantum_machine_backend, shots = 1).result()

# %%
plot_histogram( legatheaux_quantum_circuit_results.get_counts( legatheaux_quantum_circuit ) )

# %%
# The results of the Quantum Measurement of States is Legatheaux's Secret Key Candidate
legatheaux_secret_key_binary_reversed = list( legatheaux_quantum_circuit_results.get_counts( legatheaux_quantum_circuit ) )[0]

# %%
# The Legatheaux's Secret Key is reversed so that
# first Qubit is the first element of the list
legatheaux_secret_key_binary = legatheaux_secret_key_binary_reversed[::-1]

# %%
legatheaux_secret_key = int(legatheaux_secret_key_binary, 2)

# %%
for final_secret_key_qubits_index, secret_key_quantum_state_basis in enumerate(zip(ruben_and_isabel_secret_key_polarisation_table, legatheaux_secret_key_filtration_measurement_table)):
    if ( ( secret_key_quantum_state_basis[0] == "↕" or secret_key_quantum_state_basis[0] == "↔" ) and secret_key_quantum_state_basis[1] == "✛"):
        print("Same basis choice for the qubit #{}: ".format(final_secret_key_qubits_index))
    elif ( ( secret_key_quantum_state_basis[0] == "⤢" or secret_key_quantum_state_basis[0] == "⤡" ) and secret_key_quantum_state_basis[1] == "✕"):
        print("Same basis choice for the qubit #{}: ".format(final_secret_key_qubits_index))
    else:
        print("Different basis choice for the qubit #{}: ".format(final_secret_key_qubits_index))

        if ( ( secret_key_quantum_state_basis[0] == "↕" or secret_key_quantum_state_basis[0] == "↔" ) and secret_key_quantum_state_basis[1] == "✕") :
            legatheaux_quantum_circuit.x( legatheaux_quantum_register[final_secret_key_qubits_index] )
            legatheaux_quantum_circuit.h( legatheaux_quantum_register[final_secret_key_qubits_index] )
        else:
            legatheaux_quantum_circuit.h( legatheaux_quantum_register[final_secret_key_qubits_index] )
            legatheaux_quantum_circuit.x( legatheaux_quantum_register[final_secret_key_qubits_index] )
        
    print(" - Basis chosen by Rúben/Isabel was: {}; ".format(secret_key_quantum_state_basis[0]))
    print(" - Basis chosen by Legatheaux was: {}; \n" .format(secret_key_quantum_state_basis[1]))
# Out:
# Same basis choice for the qubit #0:
#  - Basis chosen by Rúben/Isabel was: ⤡;
#  - Basis chosen by Legatheaux was: ✕;
#
# Different basis choice for the qubit #1:
#  - Basis chosen by Rúben/Isabel was: ↕;
#  - Basis chosen by Legatheaux was: ✕;
#
# Different basis choice for the qubit #2:
#  - Basis chosen by Rúben/Isabel was: ↔;
#  - Basis chosen by Legatheaux was: ✕;
#
# Different basis choice for the qubit #3:
#  - Basis chosen by Rúben/Isabel was: ↔;
#  - Basis chosen by Legatheaux was: ✕;
#
# Same basis choice for the qubit #4:
#  - Basis chosen by Rúben/Isabel was: ⤢;
#  - Basis chosen by Legatheaux was: ✕;
#
# Same basis choice for the qubit #5:
#  - Basis chosen by Rúben/Isabel was: ⤡;
#  - Basis chosen by Legatheaux was: ✕;
#
# Same basis choice for the qubit #6:
#  - Basis chosen by Rúben/Isabel was: ↔;
#  - Basis chosen by Legatheaux was: ✛;
#
# Same basis choice for the qubit #7:
#  - Basis chosen by Rúben/Isabel was: ↕;
#  - Basis chosen by Legatheaux was: ✛;
#
# ...

# %%
send_quantum_state(legatheaux_quantum_circuit, eleni_quantum_circuit, eleni_quantum_register)

# %%
# The Eleni's Secret Key Filtration for Measurement Table
eleni_secret_key_filtration_measurement_table = []

# %%
for eleni_secret_key_index in range(len(eleni_quantum_register)):
    
    eleni_filtration_measurement_axis = np.random.random()
    
    # Rectilinear Filter Up/Down/Left/Right (✛) for Measurement of a Polarised Photon/Qubit
    if ( (eleni_filtration_measurement_axis >= 0.0) and (eleni_filtration_measurement_axis < 0.25) ) or ( (eleni_filtration_measurement_axis >= 0.5) and (eleni_filtration_measurement_axis < 0.75) ):
    
        # Saves the Rectilinear Filter Up/Down/Left/Right (✛) for Measumerement of a Polarised Photon/Qubit in
        # the Eleni's Secret Key Filtration for Measurements Table
        eleni_secret_key_filtration_measurement_table.append("✛")
    
    # Diagonal North East/South West / North West/South East (✕) for Measurement of a Polarised Photon/Qubit
    elif ( (eleni_filtration_measurement_axis >= 0.25) and (eleni_filtration_measurement_axis < 0.5) ) or ( (eleni_filtration_measurement_axis >= 0.75) and (eleni_filtration_measurement_axis <= 1.0) ):   
        
        # Puts the current qubit in Quantum Superposition of States,
        # using a Hadamard Quantum Logic Gate
        eleni_quantum_circuit.h(eleni_quantum_register[eleni_secret_key_index])

        # Saves the Diagonal North East/South West / North West/South East (✕) for Measurement of a Polarised Photon/Qubit in
        # the Eleni's Secret Key Polarisation Table
        eleni_secret_key_filtration_measurement_table.append("✕")

# %%
print("The Final Filtration for Measurements for Eleni's Secret Key is:")
eleni_secret_key_filtration_measurement_table
# Out:
# The Final Filtration for Measurements for Eleni's Secret Key is:
# ['✕', '✕', '✛', '✕', '✛', '✛', '✛', '✛', '✛', '✛', '✕', '✕', '✕', '✕', '✛']

# %%
# Measure all Qubits of the Eleni's Quantum Circuit
for qubit_index in range(len(eleni_quantum_register)): 
    eleni_quantum_circuit.measure(eleni_quantum_register[qubit_index], eleni_classical_register[qubit_index])

# %%
eleni_quantum_circuit.draw(output = "mpl")

# %%
# Execute the Eleni's Quantum Circuit 
quantum_machine_backend = BasicAer.get_backend('qasm_simulator')    
eleni_quantum_circuit_results = execute(eleni_quantum_circuit, backend = quantum_machine_backend, shots = 1).result()

# %%
# Execute the Eleni's Quantum Circuit 
#quantum_machine_backend = my_provider.get_backend('ibmq_16_melbourne')      
#eleni_quantum_circuit_results = execute(eleni_quantum_circuit, backend = quantum_machine_backend, shots = 1).result()

# %%
plot_histogram( eleni_quantum_circuit_results.get_counts( eleni_quantum_circuit ) )

# %%
# The results of the Quantum Measurement of States is Eleni's Secret Key Candidate
eleni_secret_key_binary_reversed = list(eleni_quantum_circuit_results.get_counts(eleni_quantum_circuit))[0]

# %%
# The Eleni's Secret Key is reversed so that
# first Qubit is the first element of the list
eleni_secret_key_binary = eleni_secret_key_binary_reversed[::-1]

# %%
eleni_secret_key = int(eleni_secret_key_binary, 2)

# %%
final_secret_key_qubits_to_keep = []
final_secret_key_qubits_to_discard = []

# %%
for final_secret_key_qubits_index, secret_key_quantum_state_basis in enumerate(zip(ruben_and_isabel_secret_key_polarisation_table, eleni_secret_key_filtration_measurement_table)):
    if ( ( secret_key_quantum_state_basis[0] == "↕" or secret_key_quantum_state_basis[0] == "↔" ) and secret_key_quantum_state_basis[1] == "✛"):
        print("Same basis choice for the qubit #{}: ".format(final_secret_key_qubits_index))
        final_secret_key_qubits_to_keep.append(final_secret_key_qubits_index)
    elif ( ( secret_key_quantum_state_basis[0] == "⤢" or secret_key_quantum_state_basis[0] == "⤡" ) and secret_key_quantum_state_basis[1] == "✕"):
        print("Same basis choice for the qubit #{}: ".format(final_secret_key_qubits_index))
        final_secret_key_qubits_to_keep.append(final_secret_key_qubits_index)
    else:
        print("Different basis choice for the qubit #{}: ".format(final_secret_key_qubits_index))
        final_secret_key_qubits_to_discard.append(final_secret_key_qubits_index)
        
    print(" - Basis chosen by Rúben/Isabel was: {}; ".format(secret_key_quantum_state_basis[0]))
    print(" - Basis chosen by Eleni was: {}; \n" .format(secret_key_quantum_state_basis[1]))
# Out:
# Same basis choice for the qubit #0:
#  - Basis chosen by Rúben/Isabel was: ⤡;
#  - Basis chosen by Eleni was: ✕;
#
# Different basis choice for the qubit #1:
#  - Basis chosen by Rúben/Isabel was: ↕;
#  - Basis chosen by Eleni was: ✕;
#
# Same basis choice for the qubit #2:
#  - Basis chosen by Rúben/Isabel was: ↔;
#  - Basis chosen by Eleni was: ✛;
#
# Different basis choice for the qubit #3:
#  - Basis chosen by Rúben/Isabel was: ↔;
#  - Basis chosen by Eleni was: ✕;
#
# Different basis choice for the qubit #4:
#  - Basis chosen by Rúben/Isabel was: ⤢;
#  - Basis chosen by Eleni was: ✛;
#
# Different basis choice for the qubit #5:
#  - Basis chosen by Rúben/Isabel was: ⤡;
#  - Basis chosen by Eleni was: ✛;
#
# Same basis choice for the qubit #6:
#  - Basis chosen by Rúben/Isabel was: ↔;
#  - Basis chosen by Eleni was: ✛;
#
# Same basis choice for the qubit #7:
#  - Basis chosen by Rúben/Isabel was: ↕;
#  - Basis chosen by Eleni was: ✛;
#
# Same basis choice for the qubit #8:
# ...

# %%
occasional_chance_accuracy = 0

# %%
for secret_key_qubit in zip(ruben_and_isabel_secret_key_binary, eleni_secret_key_binary):
    if ( secret_key_qubit[0] == secret_key_qubit[1] ):
        occasional_chance_accuracy += 1

# %%
percentage_qubits_to_keep = ( len( final_secret_key_qubits_to_keep ) / num_qubits )

# %%
measurement_convergence = ( occasional_chance_accuracy / num_qubits )

# %%
print("Percentage of Qubits (Quantum Bits) to be kept, according to Polarisation and Filtration for Measurements Tables comparison: \n - {} \n". format( percentage_qubits_to_keep ) )
print("Measurement convergence, i.e., the percentage of Qubits (Quantum Bits), occasionally, measured in the same basis), by additional occasional chance: \n - {}" .format( measurement_convergence ) )
# Out:
# Percentage of Qubits (Quantum Bits) to be kept, according to Polarisation and Filtration for Measurements Tables comparison:
#  - 0.6
#
# Measurement convergence, i.e., the percentage of Qubits (Quantum Bits), occasionally, measured in the same basis), by additional occasional chance:
#  - 0.7333333333333333

# %%
ruben_and_isabel_final_secret_key_binary = [ruben_and_isabel_secret_key_binary[qubit_index] for qubit_index in final_secret_key_qubits_to_keep]
eleni_final_secret_key_binary = [eleni_secret_key_binary[qubit_index] for qubit_index in final_secret_key_qubits_to_keep]

# %%
final_accuracy_after_different_basis_discarded = 0

# %%
for final_secret_key_qubit in zip(ruben_and_isabel_final_secret_key_binary, eleni_final_secret_key_binary):
    if ( final_secret_key_qubit[0] == final_secret_key_qubit[1] ):
        final_accuracy_after_different_basis_discarded += 1

# %%
percentage_simlarity_final_secret_keys = final_accuracy_after_different_basis_discarded / len(ruben_and_isabel_final_secret_key_binary)

# %%
# NOTE: This should can be true or false, in a situation of existence of Eavesdropping and
#       after discarding the Qubits measured in the different basis,
#       i.e., the Percentage of Similarity between the Rúben's/Isabel's and Eleni's Final Secret Key,
#       after the Qubits measured in different basis, should be less than 1.0 (100%)
if (ruben_and_isabel_final_secret_key_binary == eleni_final_secret_key_binary) :
    print("The Secret Key exchange seems to worked fine and be completely secure!!!")
    
print("Percentage of Similarity between the Rúben's/Isabel's and Eleni's Final Secret Key, after the Qubits measured in different basis: \n - {}" .format( percentage_simlarity_final_secret_keys ) )
# Out:
# Percentage of Similarity between the Rúben's/Isabel's and Eleni's Final Secret Key, after the Qubits measured in different basis:
#  - 0.8888888888888888

# %%
ruben_and_isabel_final_secret_key = int("".join(str(binary_digit) for binary_digit in ruben_and_isabel_final_secret_key_binary), 2) 
eleni_final_secret_key = int("".join(str(binary_digit) for binary_digit in eleni_final_secret_key_binary), 2)

# %%
# The Secret Key wan't tampered and it's the same for both parties
if (percentage_simlarity_final_secret_keys == 1):
    print("The Secret Key exchange has been successfull!!! \n")
    print(" - Rúben's/Isabel's Final Secret Key, in binary: \n  - ", ruben_and_isabel_final_secret_key_binary)
    print(" - Eleni's Final Secret Key, in binary: \n  - ", eleni_final_secret_key_binary)
    print("\n")
    print(" - Rúben's/Isabel's Final Secret Key: \n  - ", ruben_and_isabel_final_secret_key)
    print(" - Eleni's Final Secret Key: \n  - ", eleni_final_secret_key)
else:
    print("The Secret Key exchange has been tampered!!!\n\n")
    print("The Eavesdropping attempt from José Legatheaux was detected!!!\n\n")
    print("It's necessary to check for the existence of some Eavesdropper or try a new Secret Key exchange again...\n\n")
    print(" - Rúben's/Isabel's Final Secret Key, in binary: \n  - ", ruben_and_isabel_final_secret_key_binary)
    print(" - Eleni's Final Secret Key, in binary: \n  - ", eleni_final_secret_key_binary)
    print("\n")
    print(" - Rúben's/Isabel's Final Secret Key: \n  - ", ruben_and_isabel_final_secret_key)
    print(" - Eleni's Final Secret Key: \n  - ", eleni_final_secret_key)
# Out:
# The Secret Key exchange has been tampered!!!
#
#
# The Eavesdropping attempt from José Legatheaux was detected!!!
#
#
# It's necessary to check for the existence of some Eavesdropper or try a new Secret Key exchange again...
#
#
#  - Rúben's/Isabel's Final Secret Key, in binary:
#   -  ['1', '1', '0', '0', '0', '0', '1', '0', '1']
#  - Eleni's Final Secret Key, in binary:
#   -  ['0', '1', '0', '0', '0', '0', '1', '0', '1']
#
#
#  - Rúben's/Isabel's Final Secret Key:
#   -  389
#  - Eleni's Final Secret Key:
#   -  133

# %%
x_secret_key_length = np.arange(0.0, 30.0)
y_probability_detect_legatheaux = ( 1 - ( ( 3 / 4 )**x_secret_key_length ) )

plt.plot(y_probability_detect_legatheaux)

plt.title('Security of the BB84 Protocol')

plt.xlabel('Size/# of Qubits (Quantum Bits) of the Secret Key compared')
plt.ylabel('Probablity of detecting Legatheaux')

plt.show()
